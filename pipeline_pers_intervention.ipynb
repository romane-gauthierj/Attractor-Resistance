# %% [markdown]
# Downstream Analysis Pipeline: try to block (knock out) differentienly expressed genes and see if impact proliferation

# %% [markdown]
# Block: FOXA1, BCL2, BIRC5

# %%
import maboss
import ginsim
import pandas as pd 
import numpy as np
import os
import shutil
from collections import defaultdict
from statsmodels.stats.power import TTestIndPower
import ast


from identification_patients.get_patients_sens_res import get_patients

from identification_drug.identification_drug import identify_drug


from create_generic_models.create_generic_patients_cfgs import create_generic_patients_cfgs_bnds

from create_generic_models.update_phenotypes_generic_models import generic_models_update_phenotypes
from pre_process_data.pre_process_genes import create_table_rna_seq_patients, process_genes

from create_person_models.tailor_cfgs_patients_gene import personalized_patients_genes_cfgs
from create_person_models.tailor_bnd_mutations import personalized_patients_mutations_bnds
from create_person_models.tailor_bnd_tsg_onco_mutations import tailor_bnd_tsg_onco_mut
from create_person_models.tailor_bnd_cnv import tailor_bnd_cnv_cm


from MaBoSS_simulation.maboss_phenotype_patient import compute_phenotype_table, compute_phenotype_mean_group_validation

from pre_process_data.identify_mutations_patients import identif_mutations_kras_egfr

# # from pre_process_profiles_table_data_lung import create_genes_patients

from stats.stats_proba import compute_mannwhitneyu_test_means, compute_kruskal
from results_MaBoSS_visualization.boxplot_phenotype import create_boxplot
from results_MaBoSS_visualization.create_phenotypes_patients_table import vizualise_table_phenotype_condition
from results_MaBoSS_visualization.patients_ids_phenotype_table import create_combined_table_patients
from gene_enrichment.genes_signature import compute_genes_mean_signature
from pre_process_data.preprocess_mutations import preprocess_mutations_ds
from pre_process_data.pre_process_cnv import preprocess_cnv



from downstream_analysis.pers_interventions import tailor_bnd_genes_intervention
# Out:
# <script type="text/javascript" id="colomoto-setup-1459945" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# function colomoto_replace_call(cell, orig, dest, args, comment=false) {
#     var call_regexp = new RegExp("\\."+orig.replace(".","\\.")+"\\(");
#     var call_replacer = new RegExp("\\."+orig.replace(".","\\.")
#                     + "\\(\\s*([^\\)]*)?\\)");
#     var code = cell.get_text();
#     var lines = code.split("\n");
#     if (args) {
#         var strargs = ", "+args.join(", ");
#     } else {
#         var strargs = "";
#     }
#     for (var i = 0; i < lines.length; ++i) {
#         if (call_regexp.test(lines[i])) {
#             var code = ""
#             if (comment) {
#                 code += "#"+lines[i]+"\n";
#             }
#             code += lines[i].replace(call_replacer, "."+dest+"($1"+strargs+")")
#             lines[i] = code;
#         }
#     }
#     cell.set_text(code)
# }
#
# function colomoto_upload(Jupyter, ssid, input, py_callback_name, orig, dest) {
#
#     function callback(out_data) {
#         var cell_element = $("#"+ssid).parents('.cell');
#         var cell_idx = Jupyter.notebook.get_cell_elements().index(cell_element);
#         var cell = Jupyter.notebook.get_cell(cell_idx);
#
#         var filename = out_data.content.text;
#
#         var code = cell.get_text();
#         code = code.replace(new RegExp("\\b" + orig.replace('.', '\\.')
#                     + "\\(\\s*((\\w+)=[^\\)]*)?\\)"),
#                 dest+"(\""+filename+"\",$1)");
#         code = code.replace('",)', '")')
#         cell.set_text(code);
#
#         Jupyter.notebook.select(cell_idx);
#         Jupyter.notebook.execute_cell_and_select_below();
#     }
#
#     if (! (window.File && window.FileReader && window.FileList && window.Blob)) {
#         alert("Interactive file upload is not supported by your browser.");
#         return;
#     }
#
#     input.disabled = true;
#     input.style.cursor = "wait";
#     input.parentElement.style.cursor = "wait";
#
#     var f = input.files[0];
#     var reader = new FileReader();
#     reader.onload = (function(f) {
#         return function (e) {
#             var obj = {
#                 content: e.target.result,
#                 name: f.name
#             };
#
#             //var pycb = py_callback_name+"("+JSON.stringify(obj)+")"
#             // hack/workaround:
#             // it seems that Jupyter does not like very long lines
#             // so we split the data in chunks
#             var chunk_length = 100;
#             var pycb = "__colomoto_upload_name = " + JSON.stringify(obj.name) + "\n";
#             pycb += "__colomoto_upload_content = \\\n";
#             for (var i = 0; i < obj.content.length; i += chunk_length) {
#                 pycb += "\"" + obj.content.substr(i, chunk_length)+"\"\\\n"
#             }
#             pycb += "\n"
#             pycb += py_callback_name+"({'name':__colomoto_upload_name, 'content': __colomoto_upload_content})\n";
#             pycb += "del __colomoto_upload_name, __colomoto_upload_content"
#
#             IPython.notebook.kernel.execute(pycb, {iopub: {output: callback}});
#         };
#     })(f);
#     reader.readAsDataURL(f);
# }
#
# function resolve_function(tool_api, funcname) {
#     if (tool_api.hasOwnProperty(funcname)) {
#         return tool_api[funcname];
#     } else {
#         return window[funcname];
#     }
# }
#
# function colomoto_extension(Jupyter, ssid, name, menu, toolbar, tool_api) {
#
#     function insert_snippet_code(snippet) {
#         var cell = Jupyter.notebook.get_selected_cell();
#         Jupyter.notebook.edit_mode();
#         cell.code_mirror.replaceSelection(snippet, 'around');
#         //cell.focus_editor();
#     }
#
#     /**
#         from https://github.com/moble/jupyter_boilerplate/blob/master/main.js
#     */
#     function callback_insert_snippet (evt) {
#         // this (or event.currentTarget, see below) always refers to the DOM
#         // element the listener was attached to - see
#         // http://stackoverflow.com/questions/12077859
#         insert_snippet_code($(evt.currentTarget).data('snippet-code'));
#     }
#     function build_menu_element (menu_item_spec, direction) {
#         // Create the menu item html element
#         var element = $('<li/>');
#
#         if (typeof menu_item_spec == 'string') {
#             if (menu_item_spec != '---') {
#                 return element.html(menu_item_spec)
#                         .addClass('ui-state-disabled')
#                         .attr({"style": "padding:2px .4em"})
#                        ;
#             }
#             return element.addClass('divider');
#         }
#
#         var a = $('<a/>')
#             .attr('href', '#')
#             .html(menu_item_spec.name)
#             .appendTo(element);
#         if (menu_item_spec.hasOwnProperty('snippet')) {
#             var snippet = menu_item_spec.snippet;
#             if (typeof snippet == 'string' || snippet instanceof String) {
#                 snippet = [snippet];
#             }
#             a.attr({
#                 'title' : "", // Do not remove this, even though it's empty!
#                 'data-snippet-code' : snippet.join('\n'),
#             })
#             .on('click', callback_insert_snippet)
#             .addClass('snippet');
#         }
#         else if (menu_item_spec.hasOwnProperty('internal-link')) {
#             a.attr('href', menu_item_spec['internal-link']);
#         }
#         else if (menu_item_spec.hasOwnProperty('external-link')) {
#             a.empty();
#             a.attr('href', menu_item_spec['external-link']);
#             a.attr({
#                 'target' : '_blank',
#                 'title' : 'Opens in a new window',
#             });
#             $('<i class="fa fa-external-link menu-icon pull-right"/>').appendTo(a);
#             $('<span/>').html(menu_item_spec.name).appendTo(a);
#         }
#
#         if (menu_item_spec.hasOwnProperty('sub-menu')) {
#             element
#                 .addClass('dropdown-submenu')
#                 .toggleClass('dropdown-submenu-left', direction === 'left');
#             var sub_element = $('<ul class="dropdown-menu"/>')
#                 .toggleClass('dropdown-menu-compact', menu_item_spec.overlay === true) // For space-saving menus
#                 .appendTo(element);
#
#             var new_direction = (menu_item_spec['sub-menu-direction'] === 'left') ? 'left' : 'right';
#             for (var j=0; j<menu_item_spec['sub-menu'].length; ++j) {
#                 var sub_menu_item_spec = build_menu_element(menu_item_spec['sub-menu'][j], new_direction);
#                 if(sub_menu_item_spec !== null) {
#                     sub_menu_item_spec.appendTo(sub_element);
#                 }
#             }
#         }
#
#         return element;
#     }
#
#     function menu_setup (menu_item_specs, sibling, insert_before_sibling) {
#         for (var i=0; i<menu_item_specs.length; ++i) {
#             var menu_item_spec;
#             if (insert_before_sibling) {
#                 menu_item_spec = menu_item_specs[i];
#             } else {
#                 menu_item_spec = menu_item_specs[menu_item_specs.length-1-i];
#             }
#             var direction = (menu_item_spec['menu-direction'] == 'left') ? 'left' : 'right';
#             var menu_element = build_menu_element(menu_item_spec, direction);
#             // We need special properties if this item is in the navbar
#             if ($(sibling).parent().is('u
# <script type="text/javascript" id="colomoto-setup-3219198" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var mymodule_jsapi = {  };
#     colomoto_extension(Jupyter, "colomoto-setup-3219198", "mymodule", {"name": "MaBoSS", "sub-menu": [{"name": "Load MaBoSS file", "snippet": ["masim = maboss.load(\"filename.bnd\", \"filename.cfg\")"]}, {"name": "Network", "sub-menu": [{"name": "Set istate", "snippet": ["maboss.wg_set_istate(masim)"]}, {"name": "Get initial state", "snippet": ["masim.get_initial_state()"]}]}, {"name": "Simulation", "sub-menu": [{"name": "Create mutant", "snippet": ["maboss.wg_make_mutant(masim)"]}, {"name": "Run", "snippet": ["simres = masim.run()"]}, {"name": "Set initial states", "snippet": ["masim.network.set_istate([\"mygenelist\"],{})"]}, {"name": "Set output", "snippet": ["maboss.wg_set_output(masim)"]}]}, {"name": "Results", "sub-menu": [{"name": "Save results", "snippet": ["simres.save(\"filename\")"]}, {"name": "Plot piechart", "snippet": ["simres.plot_piechart()"]}, {"name": "Plot trajectory", "snippet": ["simres.plot_trajectory()"]}]}, {"name": "Conversion", "sub-menu": [{"name": "Convert to biolqm", "snippet": ["biolqm_model = maboss.to_biolqm(masim)"]}, {"name": "Convert to minibn", "snippet": ["minibn_model = maboss.to_minibn(masim)"]}]}, "---", {"name": "Documentation", "external-link": "http://pymaboss.readthedocs.io"}]}, null, mymodule_jsapi);
#      }</script><style type="text/css">
#     #mymodule_menu {
#         color: green;
#         background-color: white;
#     }
#     </style>
# <script type="text/javascript" id="colomoto-setup-4279703" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var biolqm_jsapi = { action_upload_model: function() {
#         var cell = Jupyter.notebook.get_selected_cell();
#         cell.set_text('lqm = '+biolqm_jsapi.module_alias+'.upload()');
#         cell.focus_editor();
#     } };
#     colomoto_extension(Jupyter, "colomoto-setup-4279703", "biolqm", {"name": "bioLQM", "sub-menu": [{"name": "Upload model", "snippet": ["lqm = biolqm.upload()"]}, {"name": "Load model", "snippet": ["lqm = biolqm.load(\"model.sbml\")"]}, "---", {"name": "Export to file", "sub-menu": [{"name": "SBML-qual v1.0 (.sbml)", "snippet": ["biolqm.save(lqm, \"mymodel.sbml\", \"sbml\")"]}, "Functions formats", {"name": "BoolNet (.bnet)", "snippet": ["biolqm.save(lqm, \"mymodel.bnet\", \"bnet\")"]}, {"name": "BooleanNet (.booleannet)", "snippet": ["biolqm.save(lqm, \"mymodel.booleannet\", \"booleannet\")"]}, {"name": "BoolSim (.boolsim)", "snippet": ["biolqm.save(lqm, \"mymodel.boolsim\", \"boolsim\")"]}, {"name": "Raw Boolean functions (.boolfunctions)", "snippet": ["biolqm.save(lqm, \"mymodel.boolfunctions\", \"boolfunctions\")"]}, {"name": "Truth table (.tt)", "snippet": ["biolqm.save(lqm, \"mymodel.tt\", \"tt\")"]}, "Petri net formats", {"name": "APNN (.apnn)", "snippet": ["biolqm.save(lqm, \"mymodel.apnn\", \"apnn\")"]}, {"name": "INA (.ina)", "snippet": ["biolqm.save(lqm, \"mymodel.ina\", \"ina\")"]}, {"name": "PNML (.pnml)", "snippet": ["biolqm.save(lqm, \"mymodel.pnml\", \"pnml\")"]}, "Dedicated formats", {"name": "GINML (.ginml)", "snippet": ["biolqm.save(lqm, \"mymodel.ginml\", \"ginml\")"]}, {"name": "GNA non-xml (.gna)", "snippet": ["biolqm.save(lqm, \"mymodel.gna\", \"gna\")"]}, {"name": "MaBoSS (.bnd)", "snippet": ["biolqm.save(lqm, \"mymodel.bnd\", \"bnd\")"]}, {"name": "Pint (.an)", "snippet": ["biolqm.save(lqm, \"mymodel.an\", \"an\")"]}]}, {"name": "Convert to tool", "sub-menu": [{"name": "GINsim", "snippet": ["lrg = biolqm.to_ginsim(lqm)"]}, {"name": "MaBoSS", "snippet": ["masim = biolqm.to_maboss(lqm)"]}, {"name": "Pint", "snippet": ["an = biolqm.to_pint(lqm)"]}]}, "---", {"name": "Compute fixpoints", "snippet": ["fps = biolqm.fixpoints(lqm)"]}, {"name": "Compute trap spaces", "snippet": ["traps = biolqm.trapspace(lqm)"]}, "---", {"name": "Model modifications", "sub-menu": [{"name": "Perturbation", "snippet": ["lqm_mod = biolqm.perturbation(lqm, \"node%0\")"]}, {"name": "Booleanization", "snippet": ["lqm_bool = biolqm.booleanize(lqm)"]}, {"name": "Reduction", "snippet": ["lqm_red = biolqm.reduce(lqm, \"fixed,output,duplicate\")"]}, {"name": "Reversal", "snippet": ["lqm_rev = biolqm.reverse(lqm)"]}, {"name": "Sanitize", "snippet": ["lqm_san = biolqm.sanitize(lqm)"]}]}, "---", {"name": "Documentation", "external-link": "http://ginsim.naldi.info/biolqm/site/doc/index.html"}]}, [{"name": "upload", "setup": {"icon": "fa-upload", "help": "Upload model", "handler": "action_upload_model"}}], biolqm_jsapi);
#      }</script><style type="text/css">
#     #biolqm_menu {
#         color: #00007f;
#         background-color: white;
#     }
#
#     div#biolqm-toolbar:before {
#         content: "bioLQM";
#         float: left;
#         margin-left: 1em;
#         margin-right: 1em;
#         margin-top: 0.2em;
#     }
#     div#biolqm-toolbar,
#     div#biolqm-toolbar button {
#         color: #00007f;
#     }
#     </style>
# <script type="text/javascript" id="colomoto-setup-1028359" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var ginsim_jsapi = { action_upload_model: function() {
#         var cell = Jupyter.notebook.get_selected_cell();
#         cell.set_text('lrg = '+ginsim_jsapi.module_alias+'.upload()');
#         cell.focus_editor();
#     } };
#     colomoto_extension(Jupyter, "colomoto-setup-1028359", "ginsim", {"name": "GINsim", "sub-menu": [{"name": "Upload model", "snippet": ["lrg = ginsim.upload()"]}, {"name": "Load model", "snippet": ["lrg = ginsim.load(\"model.zginml\")"]}, "---", {"name": "Export to file", "sub-menu": [{"name": "MaBoSS (.bnd, .cfg)", "snippet": ["ginsim.service(\"maboss\").export(lrg, \"mymodel.bnd\")"]}]}, {"name": "Convert to tool", "sub-menu": [{"name": "bioLQM", "snippet": ["lqm = ginsim.to_biolqm(lrg)"]}, {"name": "MaBoSS", "snippet": ["masim = ginsim.to_maboss(lrg)"]}, {"name": "NuSMV", "snippet": ["smv = ginsim.to_nusmv(lrg)"]}, {"name": "Pint", "snippet": ["an = ginsim.to_pint(lrg)"]}]}, "---", {"name": " Display regulatory graph", "snippet": ["ginsim.show(lrg)"]}]}, [{"name": "upload", "setup": {"icon": "fa-upload", "help": "Upload model", "handler": "action_upload_model"}}], ginsim_jsapi);
#      }</script><style type="text/css">
#     #ginsim_menu {
#         color: blue;
#         background-color: white;
#     }
#
#     div#ginsim-toolbar:before {
#         content: "GINsim";
#         float: left;
#         margin-left: 1em;
#         margin-right: 1em;
#         margin-top: 0.2em;
#     }
#     div#ginsim-toolbar,
#     div#ginsim-toolbar button {
#         color: blue;
#     }
#     </style>

# %% [markdown]
# Step 0: Import data

# %%
# Import Data

annotations_models = pd.read_csv('data/model_list_20250407.csv')
mutations_data = pd.read_csv('data/mutations_all_20250318.csv')
drug_data = pd.read_csv('data/drug_sensitivity.csv')

montagud_data = (
    pd.read_csv('data/Montagud_inter_nodes_data.csv', header=1)
    .loc[:, ['Target node', 'Interaction type', 'Source']])
rna_seq_data = pd.read_csv('data/rnaseq_merged/rnaseq_merged_20250117.csv')
cnv_data = pd.read_csv('data/cellmodel_data/cnv_summary_20250207.csv')


models_depmap_annotation = pd.read_csv('data/cellmodel_data/model_list_20250423.csv')
mutations_data_depseq = pd.read_csv('data/depmap_data/OmicsSomaticMutations.csv')
# Out:
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_37565/4029099413.py:15: DtypeWarning: Columns (22,50,56,57,58,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   mutations_data_depseq = pd.read_csv('data/depmap_data/OmicsSomaticMutations.csv')

# %% [markdown]
# Step 1: Identify the best drug to keep (the one with most resistant and sensitive, and with big variance)
#         & specify the phenotypes of our model

# %%
tissue_remove = 'Haematopoietic and Lymphoid'
# drugs_df = identify_drug(drug_data, annotations_models, tissue_remove)

# %%
drug_interest = 'Refametinib' #Pictilisib, 'Avagacestat' AZD8931 
tissue_interest = 'PAN_CANCER'


type_models = 'genes_models'


# models inputs
inputs_list = ['EGF', 'FGF', 'TGFB', 'Androgen', 'Hypoxia', 'Nutrients', 'Carcinogen', 'Acidosis', 'TNF', 'SPOP']


# models outputs
phenotype_interest = ["Proliferation","Invasion","DNA_Repair","Migration","Apoptosis"]

# %% [markdown]
# Step 2: Create the folders where the models are saved and where the results will be saved

# %%
# folder where the results will be saved
folder_result = f'results/{drug_interest}_{tissue_interest}_intervention'

folder_pers_models=f'models/personalized_boolean_{drug_interest}_{tissue_interest}_intervention'




# Generic model that will be duplicated to create personalized models
folder_generic_models = f'{folder_pers_models}/generic_models'


src_dir_generic_models = f'models/prostate/generic/{type_models}'

# copy the generic model from the models to validation generic models

folder_generic_models_cfg = f'{folder_generic_models}/Montagud2022_Prostate_Cancer.cfg'
folder_generic_models_bnd = f'{folder_generic_models}/Montagud2022_Prostate_Cancer.bnd'


folder_res_results_single_input = f'{folder_result}/resistant_results/only_gene_expression/single_input_on'
folder_sens_results_single_input = f'{folder_result}/sensitive_results/only_gene_expression/single_input_on'



folder_result_resistant = f'{folder_res_results_single_input}/phenotype_distribution_patients'
folder_result_sensitive = f'{folder_sens_results_single_input}/phenotype_distribution_patients'

folder_result_res_sen = f'{folder_result}/sensitive_resistant_results/genes_diff_expressed'


generic_pers_models_folder_res = f"{folder_pers_models}/resistant_patient/generic_models"
generic_pers_models_folder_sens = f"{folder_pers_models}/sensitive_patient/generic_models"

folder_models_res = f'{folder_pers_models}/resistant_patient/personalized_boolean_modified/models_gene_expression'
folder_models_sens = f'{folder_pers_models}/sensitive_patient/personalized_boolean_modified/models_gene_expression'




results_mean_folder_res = f"{folder_res_results_single_input}/phenotype_mean"
results_mean_folder_sens = f"{folder_sens_results_single_input}/phenotype_mean"



os.makedirs(folder_result_resistant, exist_ok=True)
os.makedirs(folder_result_sensitive, exist_ok=True)
os.makedirs(folder_result_res_sen, exist_ok=True)

os.makedirs(folder_generic_models, exist_ok=True)
os.makedirs(folder_models_res, exist_ok=True)
os.makedirs(folder_models_sens, exist_ok=True)

os.makedirs(results_mean_folder_res, exist_ok=True)
os.makedirs(results_mean_folder_res, exist_ok=True)

for filename in os.listdir(src_dir_generic_models):
    src_file = os.path.join(src_dir_generic_models, filename)
    dst_file = os.path.join(folder_generic_models, filename)
    if os.path.isfile(src_file):
        shutil.copy(src_file, dst_file)

# %% [markdown]
# Step 3: Get the n top patients Ids

# %%
# top_resistant_ids, top_sensitive_ids= get_patients(drug_data, annotations_models, drug_interest, tissue_interest)
top_resistant_ids, top_sensitive_ids, drug_tissue_data= get_patients(20, drug_data, annotations_models, drug_interest, tissue_interest = None, tissue_remove = tissue_remove)
patients_ids = top_sensitive_ids + top_resistant_ids
# Out:
# /Users/romane/repos/icr/Attractor-Resistance/identification_patients/get_patients_sens_res.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   annotations_models_filtered.rename(

# %% [markdown]
# Step 4: Pre-process data- Montagud nodes, rna-seq (filtered with patients IDs and Montagud nodes)

# %%
# Pre-process Montagud nodes

# Keep only the nodes of montagud not specific to Prostate 
montagud_nodes = list(set(montagud_data['Target node'].tolist() + montagud_data['Source'].tolist()))
montagud_nodes = [node for node in montagud_nodes if node != '0/1']
montagud_nodes = [node.upper() for node in montagud_nodes if isinstance(node, str)]
to_remove = ['FUSED_EVENT', 'AR_ERG']

montagud_nodes = [node for node in montagud_nodes if node not in to_remove]
montagud_nodes = list(set(montagud_nodes))

# %%
# Pre-process RNA seq data (keep only montagud_nodes and patients ids) and create table for high and low expression
rna_seq_data_filtered = process_genes(patients_ids, montagud_nodes, rna_seq_data)
table_rna_seq_patients = create_table_rna_seq_patients(rna_seq_data_filtered)
# Out:
# /Users/romane/repos/icr/Attractor-Resistance/pre_process_data/pre_process_genes.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rna_seq_data.rename(columns={"gene_symbol": "gene_name"}, inplace=True)

# %%
# Pre-process patients (keep only the patients id with gene expression data)

top_resistant_ids = list(set(table_rna_seq_patients.index) & set(top_resistant_ids))
top_sensitive_ids= list(set(table_rna_seq_patients.index) & set(top_sensitive_ids))

patients_ids = top_resistant_ids + top_sensitive_ids

# %%
# mutations_data_filtered_combined = preprocess_mutations_ds(patients_ids, models_depmap_annotation, mutations_data_depseq,montagud_nodes)
# print(mutations_data_filtered_combined)

# %%
# preprocess cnv data
cnv_data_filtered = preprocess_cnv(cnv_data, montagud_nodes,patients_ids)

# %% [markdown]
# Step 5: Create generic boolean networks with the sensitive and resistant ID names

# %%
create_generic_patients_cfgs_bnds(folder_generic_models_cfg, folder_generic_models_bnd, folder_pers_models, top_resistant_ids, top_sensitive_ids, drug_interest, tissue_interest)


## specify the phenotypes of interest for the analysis
generic_models_update_phenotypes(phenotype_interest, generic_pers_models_folder_res, generic_pers_models_folder_res)
generic_models_update_phenotypes(phenotype_interest, generic_pers_models_folder_sens, generic_pers_models_folder_sens)
# Out:
# All .cfg and .bnd files created for sensitive and resistant patients.
# Updated Carcinogen.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated CASP9.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated Apoptosis.is_internal=0 in SIDM00719_Refametinib.cfg
# Updated FRS2.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated JUN.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated MED12.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated E2F1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated AKT.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated Invasion.is_internal=0 in SIDM00719_Refametinib.cfg
# Updated AR.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated Hypoxia.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated PHDS.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated FGFR3.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated ETV1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated NF1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated BAD.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated CASP3.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated BAX.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated DAXX.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated RAF.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated PIP3.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated TGFB.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated CFLAR.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated SLUG.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated APAF1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated SHH.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated ATM.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated ERG.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated HIF1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated P21.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated CASP8.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated MTORC1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated ZBTB17.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated IDH1.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated COX4I2.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated NKX31.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated ERK.is_internal=1 in SIDM00719_Refametinib.cfg
# Updated EMT.is_internal=1 in SIDM00719_Refametinib.cfg
# Upd
Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00255_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00524_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00770_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00292_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00870_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00444_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00508_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00892_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00971_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00881_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00767_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00920_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM01056_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00631_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00255_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00719_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM01120_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00183_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00506_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00716_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00870_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00444_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00508_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00892_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00524_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00770_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/resistant_patient/personalized_boolean_modified/models_gene_expression/SIDM00292_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00890_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00129_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01242_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00619_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01059_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00910_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01066_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00284_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00826_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00003_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00190_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00175_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01240_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00568_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00056_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00974_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00337_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00795_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01001_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01059_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00619_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00890_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00129_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01242_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00175_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01240_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00568_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00056_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00974_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00795_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00337_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01001_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00910_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00284_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM01066_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00826_Refametinib.bnd
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00003_Refametinib.cfg
# Modified and saved: models/personalized_boolean_Refametinib_PAN_CANCER_intervention/sensitive_patient/personalized_boolean_modified/models_gene_expression/SIDM00190_Refametinib.cfg

# %% [markdown]
# Personalize the cfg files with the "simulated KO" of FOXA1, BCL2, and BIRC5

# %%
list_genes_interv = ["FOXA1", "BCL2", "BIRC5"]

tailor_bnd_genes_intervention(list_genes_interv, top_resistant_ids, folder_models_res, tissue_interest)
# Out:
# 🔍 Processing patient SIDM00920, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00920_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00881, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00881_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00767, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00767_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00508, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00508_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM01120, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM01120_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00524, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00524_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00255, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00255_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00444, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00444_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00770, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00770_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00719, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00719_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00971, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00971_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00506, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00506_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM01056, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM01056_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00631, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00631_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00716, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00716_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00870, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00870_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00892, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00892_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00292, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00292_Refametinib: CNV — nodes modified
# 🔍 Processing patient SIDM00183, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: BIRC5
# BIRC5 node found. Replacing...
# SIDM00183_Refametinib: CNV — nodes modified

# %%
# Identification of which patients id have KRAS or EGFR mutation personalize the bnd files with the mutations common to Lung (KRAS/ EGFR)


# personalized_patients_mutations_bnds(mutations_data,patients_ids,folder_models_res, drug_interest)
# personalized_patients_mutations_bnds(mutations_data,patients_ids,folder_models_sens, drug_interest)

# %%
# personalize copy nb variation

tailor_bnd_cnv_cm(cnv_data_filtered,folder_models_res, folder_models_sens, drug_interest)
# Out:
# 🔍 Processing patient SIDM00175, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00175, gene: BCL2
# BCL2 node found. Replacing...
# SIDM00175: CNV — nodes modified
# 🔍 Processing patient SIDM00920, gene: DAXX
# Patient SIDM00920 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: EZH2
# Patient SIDM00920 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: JUN
# Patient SIDM00920 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: MYC
# Patient SIDM00920 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: NCOR1
# Patient SIDM00920 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: NCOR2
# Patient SIDM00920 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00920, gene: SMO
# Patient SIDM00920 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# SIDM00920: CNV — nodes modified
# 🔍 Processing patient SIDM00881, gene: RB1
# Patient SIDM00881 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: BRCA2
# Patient SIDM00881 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: BCL2
# Patient SIDM00881 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: EP300
# Patient SIDM00881 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: FGFR3
# Patient SIDM00881 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: JUN
# Patient SIDM00881 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: MDM2
# Patient SIDM00881 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: NCOR1
# Patient SIDM00881 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: NF1
# Patient SIDM00881 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: MYC
# Patient SIDM00881 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: SPOP
# Patient SIDM00881 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: BAX
# Patient SIDM00881 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: AXIN1
# Patient SIDM00881 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00881, gene: AR
# Patient SIDM00881 is in both gain and loss groups. Please review.
# AR node found. Replacing...
# SIDM00881: CNV — nodes modified
# 🔍 Processing patient SIDM00129, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00129, gene: NCOR1
# NCOR1 node found. Replacing...
# SIDM00129: CNV — nodes modified
# 🔍 Processing patient SIDM00767, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00767, gene: PTCH1
# PTCH1 node found. Replacing...
# SIDM00767: CNV — nodes modified
# 🔍 Processing patient SIDM00974, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00974, gene: FOXA1
# FOXA1 node found. Replacing...
# SIDM00974: CNV — nodes modified
# 🔍 Processing patient SIDM00508, gene: NCOR1
# Patient SIDM00508 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: RB1
# Patient SIDM00508 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: ATR
# Patient SIDM00508 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: EP300
# Patient SIDM00508 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: FGFR3
# Patient SIDM00508 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: VHL
# Patient SIDM00508 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: BAX
# Patient SIDM00508 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: BCL2
# Patient SIDM00508 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: ERG
# Patient SIDM00508 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00508, gene: TERT
# Patient SIDM00508 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# SIDM00508: CNV — nodes modified
# 🔍 Processing patient SIDM00337, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00337, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00337, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00337, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00337, gene: PTEN
# PTEN node found. Replacing...
# SIDM00337: CNV — nodes modified
# 🔍 Processing patient SIDM01120, gene: BRCA2
# Patient SIDM01120 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: RB1
# Patient SIDM01120 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: EP300
# Patient SIDM01120 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: FGFR3
# Patient SIDM01120 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: NCOR1
# Patient SIDM01120 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: PTCH1
# Patient SIDM01120 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: SMO
# Patient SIDM01120 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: SPOP
# Patient SIDM01120 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: TERT
# Patient SIDM01120 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: EZH2
# Patient SIDM01120 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: ERG
# Patient SIDM01120 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: EGFR
# Patient SIDM01120 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: DAXX
# Patient SIDM01120 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM01120, gene: ATR
# Patient SIDM01120 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# SIDM01120: CNV — nodes modified
# 🔍 Processing patient SIDM00524, gene: VHL
# Patient SIDM00524 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: SMO
# Patient SIDM00524 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: VHL
# Patient SIDM00524 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: BRCA2
# Patient SIDM00524 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: FGFR3
# Patient SIDM00524 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: MDM2
# Patient SIDM00524 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: NCOR1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: PTCH1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: PTEN
# Patient SIDM00524 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: RB1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: NCOR1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: FOXA1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: RB1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: PTEN
# Patient SIDM00524 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: ATM
# Patient SIDM00524 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: EP300
# Patient SIDM00524 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: SMO
# Patient SIDM00524 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: MYC
# Patient SIDM00524 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: FOXA1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: EZH2
# Patient SIDM00524 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: EGFR
# Patient SIDM00524 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: ATM
# Patient SIDM00524 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: MDM2
# Patient SIDM00524 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: ETV1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: EP300
# Patient SIDM00524 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: FGFR3
# Patient SIDM00524 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: PTCH1
# Patient SIDM00524 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: MYC
# Patient SIDM00524 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00524, gene: BRCA2
# Patient SIDM00524 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# SIDM00524: CNV — nodes modified
# 🔍 Processing patient SIDM00910, gene: SPOP
# Patient SIDM00910 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00910, gene: BRCA1
# Patient SIDM00910 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00910, gene: JUN
# Patient SIDM00910 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# SIDM00910: CNV — nodes modified
# 🔍 Processing patient SIDM00255, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00255, gene: EGFR
# EGFR node found. Replacing...
# SIDM00255: CNV — nodes modified
# 🔍 Processing patient SIDM00444, gene: TERT
# Patient SIDM00444 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: MYC
# Patient SIDM00444 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: MDM2
# Patient SIDM00444 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: SMO
# Patient SIDM00444 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: NCOR2
# Patient SIDM00444 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: AXIN1
# Patient SIDM00444 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: BCL2
# Patient SIDM00444 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: EGFR
# Patient SIDM00444 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: ETV1
# Patient SIDM00444 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00444, gene: EZH2
# Patient SIDM00444 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# SIDM00444: CNV — nodes modified
# 🔍 Processing patient SIDM00770, gene: FGFR3
# Patient SIDM00770 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: TERT
# Patient SIDM00770 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: ATR
# Patient SIDM00770 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: BCL2
# Patient SIDM00770 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: NCOR2
# Patient SIDM00770 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: RB1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: AXIN1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: MYC
# Patient SIDM00770 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: ETV1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: EP300
# Patient SIDM00770 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: DAXX
# Patient SIDM00770 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: TERT
# Patient SIDM00770 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: FOXA1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: RB1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: VHL
# Patient SIDM00770 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: FGFR3
# Patient SIDM00770 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: VHL
# Patient SIDM00770 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00770, gene: PTCH1
# Patient SIDM00770 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# SIDM00770: CNV — nodes modified
# 🔍 Processing patient SIDM00719, gene: PTCH1
# Patient SIDM00719 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: PTEN
# Patient SIDM00719 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: VHL
# Patient SIDM00719 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: NCOR1
# Patient SIDM00719 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: RB1
# Patient SIDM00719 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: ATR
# Patient SIDM00719 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: BAX
# Patient SIDM00719 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: BRCA2
# Patient SIDM00719 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: EP300
# Patient SIDM00719 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: FGFR3
# Patient SIDM00719 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: ERG
# Patient SIDM00719 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00719, gene: MYC
# Patient SIDM00719 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# SIDM00719: CNV — nodes modified
# 🔍 Processing patient SIDM01059, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM01059, gene: ETV1
# ETV1 node found. Replacing...
# SIDM01059: CNV — nodes modified
# 🔍 Processing patient SIDM00971, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00971, gene: ATM
# ATM node found. Replacing...
# SIDM00971: CNV — nodes modified
# 🔍 Processing patient SIDM00506, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00506, gene: VHL
# VHL node found. Replacing...
# SIDM00506: CNV — nodes modified
# 🔍 Processing patient SIDM01056, gene: NCOR2
# Patient SIDM01056 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: MYC
# Patient SIDM01056 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: MDM2
# Patient SIDM01056 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: DAXX
# Patient SIDM01056 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: BRCA2
# Patient SIDM01056 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: AXIN1
# Patient SIDM01056 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: ATR
# Patient SIDM01056 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: RB1
# Patient SIDM01056 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: BRCA1
# Patient SIDM01056 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: NCOR1
# Patient SIDM01056 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: PTEN
# Patient SIDM01056 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: SMO
# Patient SIDM01056 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: BCL2
# Patient SIDM01056 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: EP300
# Patient SIDM01056 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM01056, gene: FGFR3
# Patient SIDM01056 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# SIDM01056: CNV — nodes modified
# 🔍 Processing patient SIDM01242, gene: MDM2
# Patient SIDM01242 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: TERT
# Patient SIDM01242 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: AR
# Patient SIDM01242 is in both gain and loss groups. Please review.
# AR node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: ATR
# Patient SIDM01242 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: PTEN
# Patient SIDM01242 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: VHL
# Patient SIDM01242 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: FGFR3
# Patient SIDM01242 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: MED12
# Patient SIDM01242 is in both gain and loss groups. Please review.
# MED12 node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: FOXA1
# Patient SIDM01242 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM01242, gene: BCL2
# Patient SIDM01242 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# SIDM01242: CNV — nodes modified
# 🔍 Processing patient SIDM00631, gene: BRCA2
# Patient SIDM00631 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: DAXX
# Patient SIDM00631 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: FOXA1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: MDM2
# Patient SIDM00631 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: MYC
# Patient SIDM00631 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: NF1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: RB1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: SPOP
# Patient SIDM00631 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: TERT
# Patient SIDM00631 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: VHL
# Patient SIDM00631 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: BRCA1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: EZH2
# Patient SIDM00631 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: IDH1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# IDH1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: ATM
# Patient SIDM00631 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: AXIN1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: BCL2
# Patient SIDM00631 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: EP300
# Patient SIDM00631 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: FGFR3
# Patient SIDM00631 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: JUN
# Patient SIDM00631 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: NCOR1
# Patient SIDM00631 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00631, gene: PTEN
# Patient SIDM00631 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# SIDM00631: CNV — nodes modified
# 🔍 Processing patient SIDM01240, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM01240, gene: MYC
# MYC node found. Replacing...
# SIDM01240: CNV — nodes modified
# 🔍 Processing patient SIDM00716, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00716, gene: EZH2
# EZH2 node found. Replacing...
# SIDM00716: CNV — nodes modified
# 🔍 Processing patient SIDM00003, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00003, gene: FGFR3
# FGFR3 node found. Replacing...
# SIDM00003: CNV — nodes modified
# 🔍 Processing patient SIDM00870, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: MED12
# MED12 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00870, gene: RB1
# RB1 node found. Replacing...
# SIDM00870: CNV — nodes modified
# 🔍 Processing patient SIDM00190, gene: PTEN
# Patient SIDM00190 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00190, gene: ATM
# Patient SIDM00190 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00190, gene: FGFR3
# Patient SIDM00190 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00190, gene: NCOR1
# Patient SIDM00190 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00190, gene: DAXX
# Patient SIDM00190 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00190, gene: SPOP
# Patient SIDM00190 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# SIDM00190: CNV — nodes modified
# 🔍 Processing patient SIDM01001, gene: RB1
# RB1 node found. Replacing...
# SIDM01001: CNV — nodes modified
# 🔍 Processing patient SIDM00056, gene: BCL2
# Patient SIDM00056 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00056, gene: SPOP
# Patient SIDM00056 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00056, gene: MYC
# Patient SIDM00056 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00056, gene: BRCA1
# Patient SIDM00056 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00056, gene: NF1
# Patient SIDM00056 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00056, gene: NCOR1
# Patient SIDM00056 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# SIDM00056: CNV — nodes modified
# 🔍 Processing patient SIDM00826, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00826, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00826, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00826, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00826, gene: DAXX
# DAXX node found. Replacing...
# SIDM00826: CNV — nodes modified
# 🔍 Processing patient SIDM01066, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM01066, gene: EZH2
# EZH2 node found. Replacing...
# SIDM01066: CNV — nodes modified
# 🔍 Processing patient SIDM00892, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00892, gene: NCOR1
# NCOR1 node found. Replacing...
# SIDM00892: CNV — nodes modified
# 🔍 Processing patient SIDM00890, gene: ATM
# Patient SIDM00890 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: PTEN
# Patient SIDM00890 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: EZH2
# Patient SIDM00890 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: SMO
# Patient SIDM00890 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: MYC
# Patient SIDM00890 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: IDH1
# Patient SIDM00890 is in both gain and loss groups. Please review.
# IDH1 node found. Replacing...
# 🔍 Processing patient SIDM00890, gene: EP300
# Patient SIDM00890 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# SIDM00890: CNV — nodes modified
# 🔍 Processing patient SIDM00568, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00568, gene: SMO
# SMO node found. Replacing...
# SIDM00568: CNV — nodes modified
# 🔍 Processing patient SIDM00619, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00619, gene: TERT
# TERT node found. Replacing...
# SIDM00619: CNV — nodes modified
# 🔍 Processing patient SIDM00292, gene: TERT
# Patient SIDM00292 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: VHL
# Patient SIDM00292 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: EP300
# Patient SIDM00292 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: NCOR1
# Patient SIDM00292 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: PTEN
# Patient SIDM00292 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: RB1
# Patient SIDM00292 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: AXIN1
# Patient SIDM00292 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: BCL2
# Patient SIDM00292 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: BRCA1
# Patient SIDM00292 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: BRCA2
# Patient SIDM00292 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: SPOP
# Patient SIDM00292 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: NF1
# Patient SIDM00292 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00292, gene: FGFR3
# Patient SIDM00292 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# SIDM00292: CNV — nodes modified
# 🔍 Processing patient SIDM00284, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient SIDM00284, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient SIDM00284, gene: SMO
# SMO node found. Replacing...
# SIDM00284: CNV — nodes modified
# 🔍 Processing patient SIDM00183, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient SIDM00183, gene: BRCA2
# BRCA2 node found. Replacing...
# SIDM00183: CNV — nodes modified

# %%
# tailor_bnd_tsg_onco_mut(mutations_data_filtered_combined,folder_models_res, folder_models_sens, drug_interest)

# %% [markdown]
# Step 7: compute the phenotype distribution

# %%
# Compute phenotype distribution for each patient

for patient  in top_resistant_ids:
    compute_phenotype_table(folder_result_resistant, folder_models_res, patient, inputs_list, phenotype_interest, drug_interest)
    
for patient  in top_sensitive_ids:
    compute_phenotype_table(folder_result_sensitive, folder_models_sens, patient, inputs_list, phenotype_interest, drug_interest)

# %%
# combine data together 
def collect_group_data(group_folder_path):
    combined_data = defaultdict(lambda: defaultdict(list))

    for file in os.listdir(group_folder_path):
        if file.startswith("_SID") and file.endswith(".csv"):
            file_path = os.path.join(group_folder_path, file)
            df = pd.read_csv(file_path, index_col=0)

            for input_name in df.index:
                for phenotype in df.columns:
                    value = df.at[input_name, phenotype]
                    combined_data[input_name][phenotype].append(float(value))

    result_df = pd.DataFrame.from_dict(combined_data, orient='index')
    result_df.to_csv(os.path.join(group_folder_path, "combined_results.csv"))

    return result_df


group_df_sens = collect_group_data(folder_result_sensitive)
group_df_res = collect_group_data(folder_result_resistant)

# %%
# stats test between the two combined dataframes (sensitive vs resistant)

# res_combined_path = "results/Refametinib_PAN_CANCER/resistant_results/only_gene_expression/single_input_on/phenotype_distribution_patients/combined_results.csv"
# sens_combined_path = "results/Refametinib_PAN_CANCER/sensitive_results/only_gene_expression/single_input_on/phenotype_distribution_patients/combined_results.csv"

df_res_combined = pd.read_csv(f'{folder_result_resistant}/combined_results.csv', index_col=0)  # index: inputs, columns: phenotypes
df_sens_combined = pd.read_csv(f'{folder_result_sensitive}/combined_results.csv', index_col=0)

# %% [markdown]
# Compute attractors phenotype mean and power calculation to count the nb of patients needed in each group

# %%
conditions = df_res_combined.index
phenotypes = df_res_combined.columns
mean_df_res_combined = pd.DataFrame(index=conditions, columns=phenotypes)


for condition, values in df_res_combined.iterrows():
    for phenotype in df_res_combined.columns:

        df_res_values = df_res_combined.loc[condition][phenotype]
        df_res_values = ast.literal_eval(df_res_values)
        mean = sum(df_res_values)/ len(df_res_values)
        mean_df_res_combined.loc[condition][phenotype] = mean
print(mean_df_res_combined)




conditions = df_sens_combined.index
phenotypes = df_sens_combined.columns
mean_df_sens_combined = pd.DataFrame(index=conditions, columns=phenotypes)


for condition, values in df_sens_combined.iterrows():
    for phenotype in df_sens_combined.columns:

        df_res_values = df_sens_combined.loc[condition][phenotype]
        df_res_values = ast.literal_eval(df_res_values)
        mean = sum(df_res_values)/ len(df_res_values)
        mean_df_sens_combined.loc[condition][phenotype] = mean
print(mean_df_sens_combined)
# Out:
#            Proliferation  Invasion DNA_Repair Migration Apoptosis
# EGF             0.713275  0.377786    0.11112  0.016846  0.517797
# FGF             0.724606  0.371877   0.110347   0.00811  0.548577
# TGFB             0.41752  0.532694   0.109402   0.01665   0.57686
# Androgen        0.713064  0.377786    0.11112  0.016846  0.517902
# Hypoxia         0.480362  0.370244   0.114163  0.007928  0.546546
# Nutrients       0.709065  0.358048   0.108682  0.006557   0.54907
# Carcinogen      0.707219  0.347287   0.594948  0.005053  0.609066
# Acidosis        0.695823  0.333614   0.109303   0.00725  0.573341
# TNF              0.22344  0.631808   0.110983  0.025968  0.595174
# SPOP            0.717687  0.369601   0.107504   0.01078  0.421153
#            Proliferation  Invasion DNA_Repair Migration Apoptosis
# EGF             0.515556  0.399102   0.150515   0.12391  0.359916
# FGF             0.497445    0.3617   0.156442  0.029609  0.436496
# TGFB            0.227462  0.603899   0.154123  0.039391    0.5074
# Androgen        0.515171  0.399418   0.150515  0.124469   0.36008
# Hypoxia         0.238541  0.356549    0.15568  0.045918  0.373408
# Nutrients       0.510726  0.363623   0.153873  0.046522  0.355905
# Carcinogen      0.488287  0.352288   0.570645  0.015023  0.560732
# Acidosis        0.475174  0.327009   0.157526  0.037583  0.389066
# TNF             0.108568  0.837862   0.159916  0.192281  0.363904
# SPOP            0.539603  0.416288   0.164427  0.092975  0.216506
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_37565/2541010860.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mean_df_res_combined.loc[condition][phenotype] = mean
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_37565/2541010860.py:29: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mean_df_sens_combined.loc[condition][phenotype] = mean

# %% [markdown]
# Power calculation for every condition-phenotype pairs

# %%
# # power calculation 

# nb_patients_required = pd.DataFrame(index=conditions, columns=phenotypes)

# for condition, values in df_res_combined.iterrows():
#     for phenotype in df_res_combined.columns:


#         data_res =  ast.literal_eval(df_res_combined.loc[condition][phenotype])
#         data_sens = ast.literal_eval(df_sens_combined.loc[condition][phenotype])

#         res_patients_mean = np.mean(data_res)
#         sens_patients_mean = np.mean(data_sens)

#         res_patients_std = np.std(data_res)
#         sens_patients_std = np.std(data_sens)

#         n_res_group = len(data_res)
#         n_sens_group = len(data_sens)
#         sd_pooled = np.sqrt(
#             ((n_res_group - 1) * res_patients_std**2 + (n_sens_group - 1) * sens_patients_std**2)
#             / (n_res_group + n_sens_group - 2)
#         )

#         d = res_patients_mean -sens_patients_mean/sd_pooled

#         analysis = TTestIndPower()
#         sample_size = analysis.solve_power(effect_size=d, power=0.8, alpha=0.05, alternative='two-sided')
#         nb_patients_required.loc[condition][phenotype] = sample_size

# print(nb_patients_required)
# print(nb_patients_required[nb_patients_required <= 20])

# %% [markdown]
# Results: using a T-test with alpha of 0.05 we will have 80% power to detect an effect size of 0.62 * StDev (ie effect > 10) with a minimum study size of 19 patients per group.

# %%
significant_kruskal_results = compute_kruskal(inputs_list, phenotype_interest, df_res_combined, df_sens_combined)
# Out:
# /Users/romane/repos/icr/Attractor-Resistance/stats/stats_proba.py:54: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   significant_kruskal_results = kruskal_results.applymap(lambda x: x if (x is not None and float(x) < 0.05) else np.nan)

# %%
significant_kruskal_results
# Out:
#             Proliferation  Invasion  DNA_Repair  Migration  Apoptosis
# EGF                   NaN       NaN         NaN   0.044622        NaN
# FGF                   NaN       NaN         NaN        NaN        NaN
# TGFB             0.008977       NaN         NaN        NaN        NaN
# Androgen              NaN       NaN         NaN   0.044622        NaN
# Hypoxia          0.034292       NaN         NaN        NaN        NaN
# Nutrients             NaN       NaN         NaN        NaN        NaN
# Carcinogen            NaN       NaN         NaN        NaN        NaN
# Acidosis              NaN       NaN         NaN   0.032962        NaN
# TNF              0.008962       NaN         NaN        NaN        NaN
# SPOP                  NaN       NaN         NaN        NaN        NaN

# %% [markdown]
# Step 7: Compute stats test between two mean datasets

# %%
# patient_res_stats_values = pd.read_csv(f'{folder_result}/resistant_results/only_gene_expression/single_input_on/patients_resistant_values_stats_{drug_interest}.csv')
# patient_sens_stats_values = pd.read_csv(f'{folder_result}/sensitive_results/only_gene_expression/single_input_on/patients_sensitive_values_stats_{drug_interest}.csv')

patient_res_stats_values =  pd.read_csv(f'{folder_result_resistant}/combined_results.csv')
patient_sens_stats_values = pd.read_csv(f'{folder_result_sensitive}/combined_results.csv')
compute_mannwhitneyu_test_means(folder_result,patient_res_stats_values, patient_sens_stats_values, drug_interest)

# %% [markdown]
# Step 8: Vizualise the boxplot of phenotype distribution output

# %%
# patient_res_values = pd.read_csv(f'{folder_result}/resistant_results/only_gene_expression/single_input_on/patients_resistant_values_stats_{drug_interest}.csv')
# patient_sens_values = pd.read_csv(f'{folder_result}/sensitive_results/only_gene_expression/single_input_on/patients_sensitive_values_stats_{drug_interest}.csv')
#data_greater_side = pd.read_csv(f'{folder_result}/sensitive_resistant_results/p_values_df_mannwhitneyu_greater_sign_{drug_interest}.csv')


data_greater_side = pd.read_csv(f'{folder_result}/sensitive_resistant_results/p_values_df_mannwhitneyu_greater_sign_Refametinib.csv')
data_less_side = pd.read_csv(f'{folder_result}/sensitive_resistant_results/p_values_df_mannwhitneyu_less_sign_Refametinib.csv')
data_both_side = pd.read_csv(f'{folder_result}/sensitive_resistant_results/p_values_df_mannwhitneyu_two_sides_Refametinib.csv')

signif_df = pd.concat([data_greater_side, data_less_side, data_both_side], axis=0)
signif_df
# Out:
#     Condition      Phenotype  Mannwhitneyu_P_value_Resistant Star_significant
# 0         EGF  Proliferation                        0.035142                *
# 1         FGF  Proliferation                        0.035142                *
# 2        TGFB  Proliferation                        0.004684               **
# 3    Androgen  Proliferation                        0.037466                *
# 4     Hypoxia  Proliferation                        0.017776                *
# 5    Acidosis  Proliferation                        0.035142                *
# 6         TNF  Proliferation                        0.004676               **
# 0         TNF       Invasion                        0.026095                *
# 1         EGF      Migration                        0.023223                *
# 2         FGF      Migration                        0.030521                *
# 3    Androgen      Migration                        0.023223                *
# 4     Hypoxia      Migration                        0.031583                *
# 5  Carcinogen      Migration                        0.038296                *
# 6    Acidosis      Migration                        0.017140                *
# 0        TGFB  Proliferation                        0.009368               **
# 1     Hypoxia  Proliferation                        0.035551                *
# 2         TNF  Proliferation                        0.009352               **
# 3         EGF      Migration                        0.046445                *
# 4    Androgen      Migration                        0.046445                *
# 5    Acidosis      Migration                        0.034281                *

# %%
create_boxplot(patient_res_stats_values, patient_sens_stats_values, signif_df)

# %% [markdown]
# Step 9: create table of patients with conditions- phenotype

# %%
res_tables_path = f'{folder_res_results_single_input}/phenotype_distribution_patients'
sens_tables_path = f'{folder_sens_results_single_input}/phenotype_distribution_patients'

# %%
patients_phenot_table = create_combined_table_patients(res_tables_path, sens_tables_path, folder_result)

# patients_phenot_table = create_table_patients_phenotypes(folder_result, dir_res_data, dir_sens_data)
# Out:
# ['SIDM00892', 'SIDM00716', 'SIDM00920', 'SIDM00506', 'SIDM00881', 'SIDM01056', 'SIDM00770', 'SIDM00767', 'SIDM01120', 'SIDM00971', 'SIDM00631', 'SIDM00183', 'SIDM00292', 'SIDM00870', 'SIDM00508', 'SIDM00444', 'SIDM00524', 'SIDM00255', 'SIDM00719', 'SIDM00890', 'SIDM00129', 'SIDM00826', 'SIDM01240', 'SIDM00003', 'SIDM00175', 'SIDM01242', 'SIDM01059', 'SIDM00795', 'SIDM00568', 'SIDM01066', 'SIDM00190', 'SIDM00619', 'SIDM00974', 'SIDM00284', 'SIDM00910', 'SIDM00337', 'SIDM01001', 'SIDM00056']
# Saved final phenotype table to: results/Refametinib_PAN_CANCER_intervention/sensitive_resistant_results/patients_phenot_table.csv

# %% [markdown]
# Step 10: Create heatmap figure

# %%
# patient_resistant_mean = pd.read_csv(f'{folder_res_results_single_input}/patients_resistant_df_mean_{drug_interest}.csv')
# patient_sensitive_mean = pd.read_csv(f'{folder_sens_results_single_input}/patients_sensitive_df_mean_{drug_interest}.csv')
# vizualise_table_phenotype_condition(folder_result, patient_resistant_mean, patient_sensitive_mean)

# %% [markdown]
# Step 11: Identify genes differently expressed in the patients with high

# %%
# identify the condition (input) and phenotype for which we observe a significant increase in resistant patients

greater_sign_results = pd.read_csv(f'{folder_result}/sensitive_resistant_results/p_values_df_mannwhitneyu_greater_sign_Refametinib.csv')
conditions_phenotypes_df = greater_sign_results[['Condition', 'Phenotype']]
conditions_phenotypes_df
# Out:
#   Condition      Phenotype
# 0       EGF  Proliferation
# 1       FGF  Proliferation
# 2      TGFB  Proliferation
# 3  Androgen  Proliferation
# 4   Hypoxia  Proliferation
# 5  Acidosis  Proliferation
# 6       TNF  Proliferation

# %%
patients_phenot_table = pd.read_csv(f'{folder_result}/sensitive_resistant_results/patients_phenot_table.csv')

# %%
# identify the patients id that show this condition-phenotype pair 

# save every gene enrichment dataframe in a dictionary of index condtion_phenotype
indexes_list = []
for condition, phenotype in conditions_phenotypes_df.values:
    indexes_list.append(f'{condition}_{phenotype}')
results_genes_enrich = {key: None for key in indexes_list}

for condition, phenotype in conditions_phenotypes_df.values:
    genes_stats_results, resistant_group_ids, sensitive_group_ids = compute_genes_mean_signature(rna_seq_data_filtered, 
    folder_result, phenotype, condition, patients_phenot_table, top_resistant_ids, top_sensitive_ids)
    if isinstance(genes_stats_results, pd.DataFrame):
        results_genes_enrich[f'{condition}_{phenotype}'] = genes_stats_results
# Out:
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/scipy/stats/_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# Step 11: check there is not correlation between phenotype distribution and cancer type

# %% [markdown]
# Gene enrichment for EGF Proliferation (as required 19 patients in each group and statistically relevant with Mannwhiteney test)

# %%
results_egf_prolif = results_genes_enrich['EGF_Proliferation']
results_egf_prolif['diff_means'] = results_egf_prolif['Group Resistant Mean'] - results_egf_prolif['Group Sensitive Mean'] 
results_egf_prolif.sort_values(by = 'P-value', ascending=True).head()

results_egf_prolif.sort_values(by = 'diff_means', ascending=False)
# Out:
#        Group Resistant Mean Group Sensitive Mean  Group Resistant Variance  \
# FOXA1              6.138972             0.810763                  4.444998
# FGFR3              3.083833             1.241584                  3.717680
# JUN                5.705689             4.275132                  1.021197
# FRS2               4.566767             3.387037                  1.863444
# BCL2               3.056356             1.890132                  4.427137
# E2F1               5.857372             4.714232                  1.133118
# APAF1              3.844061             2.972342                  0.885300
# EZH2               6.094678             5.226942                  1.163182
# BIRC5              6.562172             5.701453                  0.608337
# BAD                6.209117             5.366679                  0.344646
# DAXX               6.025833             5.457889                  0.383577
# SPOP               5.574172             5.069658                  0.410862
# ZBTB17             4.727217             4.314563                  0.645966
# MED12              4.491372             4.101284                  0.364108
# COX4I2             0.115033                  0.0                  0.072946
# FADD               4.592983             5.133963                  0.884773
# LDHA               8.999633             9.738868                  0.698748
# IDH1               5.679211             6.567505                  0.773787
# ATM                4.312211             5.328063                  1.296277
# MXI1               4.400678             5.544974                  1.174067
# RUNX2              1.026194             2.275816                  0.785088
# TWIST1               1.8141             3.419421                  4.216184
# SMO                1.403667             3.240321                  2.211526
# ETV1               2.108478             4.191405                  3.784108
# MYC                3.923439             6.088716                  6.821529
# ETS1               2.045839             5.266421                  4.957601
#
#         Group Sensitive Variance   P-value diff_means
# FOXA1                   1.357682  0.000005   5.328209
# FGFR3                   2.620573  0.002038   1.842249
# JUN                     3.323063  0.005948   1.430557
# FRS2                    0.776740  0.001840    1.17973
# BCL2                    0.786149  0.033114   1.166224
# E2F1                    0.566966  0.000574   1.143141
# APAF1                   0.349764  0.001728   0.871719
# EZH2                    0.984916  0.015358   0.867736
# BIRC5                   1.021507  0.006602    0.86072
# BAD                     0.348568  0.000112   0.842438
# DAXX                    0.477767  0.012696   0.567944
# SPOP                    0.610452  0.039361   0.504514
# ZBTB17                  0.122626  0.048560   0.412654
# MED12                   0.229501  0.035752   0.390088
# COX4I2                  0.000000  0.003328   0.115033
# FADD                    0.445278  0.003709   -0.54098
# LDHA                    0.690270  0.010686  -0.739235
# IDH1                    0.627561  0.002685  -0.888294
# ATM                     1.428368  0.012172  -1.015852
# MXI1                    1.797027  0.007357  -1.144296
# RUNX2                   2.002527  0.002933  -1.249621
# TWIST1                  2.874976  0.043283  -1.605321
# SMO                     3.072683  0.010686  -1.836654
# ETV1                    1.891655  0.002041  -2.082927
# MYC                     3.080084  0.015703  -2.165277
# ETS1                    3.092306  0.000251  -3.220582

# %% [markdown]
# Results:
# - FOXA1: TF, key roles in hormone receptor signaling and modulates tumor growth and metastatic potential
# - FGFR3: receptor tyrosine kinase for FGF ligands, promoting cell prolif (frequently overexpressed in cancers)
# - FRS2: overexpressed in several cancers, enhancing proliferative/ migratory responses
# - BCL2, BIRC5: anti-apoptotic protein -> promotes cell survival by inhibiting programmed cell death pathways; for overepxressed in cancer to evade apoptois.
# - EZH2: silencing TSG via H3K27 trimethylation, overexpression linked to aggressive, proliferative cancers

# %%
len(resistant_group_ids)
len(sensitive_group_ids)
# Out:
# 19

# %% [markdown]
# Identify if this FOXA1 overexpression is not related to tissue

# %%
resistant_group_ids_models = annotations_models[annotations_models['model_id'].isin(resistant_group_ids)].copy()
sensitive_group_ids_models = annotations_models[annotations_models['model_id'].isin(sensitive_group_ids)].copy()

# %%
resistant_counts = resistant_group_ids_models['tissue'].value_counts()
total_counts = annotations_models['tissue'].value_counts()
fraction_resistant = resistant_counts / total_counts
print(fraction_resistant[fraction_resistant.notna()])


sensitive_counts = sensitive_group_ids_models['tissue'].value_counts()
total_counts_sens = annotations_models['tissue'].value_counts()
fraction_sensitive = sensitive_counts / total_counts_sens
print(fraction_sensitive[fraction_sensitive.notna()])
# Out:
# tissue
# BREAST                       0.060976
# LUNG                         0.018927
# PERIPHERAL NERVOUS SYSTEM    0.019608
# Name: count, dtype: float64
# tissue
# BREAST                       0.012195
# LARGE INTESTINE              0.004505
# PERIPHERAL NERVOUS SYSTEM    0.019608
# SKIN                         0.096296
# STOMACH                      0.019231
# THYROID                      0.080000
# Name: count, dtype: float64

# %% [markdown]
# Result: As the ratio do not vary that much, the results observed do not seem to be tissue-dependent

# %%
resistant_counts = resistant_group_ids_models['gender'].value_counts()
total_counts = annotations_models['gender'].value_counts()
fraction_resistant = resistant_counts / total_counts
print(fraction_resistant[fraction_resistant.notna()])


sensitive_counts = sensitive_group_ids_models['gender'].value_counts()
total_counts_sens = annotations_models['gender'].value_counts()
fraction_sensitive = sensitive_counts / total_counts_sens
print(fraction_sensitive[fraction_sensitive.notna()])
# Out:
# gender
# Female     0.007018
# Male       0.004223
# Unknown    0.004444
# Name: count, dtype: float64
# gender
# Female    0.009357
# Male      0.009291
# Name: count, dtype: float64

# %% [markdown]
# Result: As the ratio do not vary that much, the results observed do not seem to be gender-dependent

# %%
# power calculation for FOXA1

foxa1_data_res = list(rna_seq_data_filtered[
    (rna_seq_data_filtered['model_id'].isin(resistant_group_ids)) &
    (rna_seq_data_filtered['gene_symbol'] == 'FOXA1')
]['rsem_tpm'])


foxa1_data_sens = list(rna_seq_data_filtered[
    (rna_seq_data_filtered['model_id'].isin(sensitive_group_ids)) &
    (rna_seq_data_filtered['gene_symbol'] == 'FOXA1')
]['rsem_tpm'])


res_patients_mean = np.mean(foxa1_data_res)
sens_patients_mean = np.mean(foxa1_data_sens)


res_patients_std = np.std(foxa1_data_res)
sens_patients_std = np.std(foxa1_data_sens)

n_res_group = len(resistant_group_ids)
n_sens_group = len(sensitive_group_ids)

sd_pooled = np.sqrt(
    ((n_res_group - 1) * res_patients_std**2 + (n_sens_group - 1) * sens_patients_std**2)
    / (n_res_group + n_sens_group - 2)
)

d = res_patients_mean -sens_patients_mean/sd_pooled


# Set parameters
effect_size = d              # Cohen's d
alpha = 0.05                 # Significance level
power = 0.80                 # Desired power
alternative = 'two-sided'    # Equivalent to "two.sample" in R

# Initialize power analysis object
analysis = TTestIndPower()

# Compute required sample size per group
sample_size = analysis.solve_power(effect_size=effect_size, power=power, alpha=alpha, alternative=alternative)

print(f"Required sample size per group: {float(sample_size):.2f}")
# Out:
# Required sample size per group: 10.00
# /Users/romane/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/statsmodels/stats/power.py:524: ConvergenceWarning:
# Failed to converge on a solution.
#
#   warnings.warn(convergence_doc, ConvergenceWarning)
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_37565/3150725304.py:45: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"Required sample size per group: {float(sample_size):.2f}")
