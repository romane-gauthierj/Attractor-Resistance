# %%
import maboss
import ginsim
import pandas as pd 
import numpy as np
import mygene
import os
import shutil
import ast
from scipy.stats import kruskal
from statsmodels.stats.multitest import multipletests
from collections import defaultdict
from pathlib import Path


from create_generic_models.create_generic_patients_cfgs import create_generic_patients_cfg_bnd_validation
from create_generic_models.update_phenotypes_generic_models import generic_models_update_phenotypes
from collections import defaultdict
from statsmodels.stats.multitest import multipletests


# from create_person_models.tailor_cfgs_patients import personalized_patients_genes_cfgs_validation
from pre_process_data.pre_process_genes import create_table_rna_seq_patients, identify_genes_synonyms

from identification_patients.validation_get_patients_ids import get_patients_valid

from pre_process_data.tcga_preprocess_data import pre_process_tcga_data

from create_person_models.tailor_cfgs_patients import personalized_patients_genes_cfgs
from create_person_models.tailor_bnd_cnv import tailor_bnd_cnv_validation

from create_person_models.tailor_bnd_tsg_onco_mutations import tailor_bnd_mutat_validation

from MaBoSS_simulation.maboss_phenotype_patient import compute_phenotype_table, compute_phenotype_mean_group_validation
from stats.stats_proba import compute_kruskal_test_means_validation
# Out:
# <script type="text/javascript" id="colomoto-setup-665693" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# function colomoto_replace_call(cell, orig, dest, args, comment=false) {
#     var call_regexp = new RegExp("\\."+orig.replace(".","\\.")+"\\(");
#     var call_replacer = new RegExp("\\."+orig.replace(".","\\.")
#                     + "\\(\\s*([^\\)]*)?\\)");
#     var code = cell.get_text();
#     var lines = code.split("\n");
#     if (args) {
#         var strargs = ", "+args.join(", ");
#     } else {
#         var strargs = "";
#     }
#     for (var i = 0; i < lines.length; ++i) {
#         if (call_regexp.test(lines[i])) {
#             var code = ""
#             if (comment) {
#                 code += "#"+lines[i]+"\n";
#             }
#             code += lines[i].replace(call_replacer, "."+dest+"($1"+strargs+")")
#             lines[i] = code;
#         }
#     }
#     cell.set_text(code)
# }
#
# function colomoto_upload(Jupyter, ssid, input, py_callback_name, orig, dest) {
#
#     function callback(out_data) {
#         var cell_element = $("#"+ssid).parents('.cell');
#         var cell_idx = Jupyter.notebook.get_cell_elements().index(cell_element);
#         var cell = Jupyter.notebook.get_cell(cell_idx);
#
#         var filename = out_data.content.text;
#
#         var code = cell.get_text();
#         code = code.replace(new RegExp("\\b" + orig.replace('.', '\\.')
#                     + "\\(\\s*((\\w+)=[^\\)]*)?\\)"),
#                 dest+"(\""+filename+"\",$1)");
#         code = code.replace('",)', '")')
#         cell.set_text(code);
#
#         Jupyter.notebook.select(cell_idx);
#         Jupyter.notebook.execute_cell_and_select_below();
#     }
#
#     if (! (window.File && window.FileReader && window.FileList && window.Blob)) {
#         alert("Interactive file upload is not supported by your browser.");
#         return;
#     }
#
#     input.disabled = true;
#     input.style.cursor = "wait";
#     input.parentElement.style.cursor = "wait";
#
#     var f = input.files[0];
#     var reader = new FileReader();
#     reader.onload = (function(f) {
#         return function (e) {
#             var obj = {
#                 content: e.target.result,
#                 name: f.name
#             };
#
#             //var pycb = py_callback_name+"("+JSON.stringify(obj)+")"
#             // hack/workaround:
#             // it seems that Jupyter does not like very long lines
#             // so we split the data in chunks
#             var chunk_length = 100;
#             var pycb = "__colomoto_upload_name = " + JSON.stringify(obj.name) + "\n";
#             pycb += "__colomoto_upload_content = \\\n";
#             for (var i = 0; i < obj.content.length; i += chunk_length) {
#                 pycb += "\"" + obj.content.substr(i, chunk_length)+"\"\\\n"
#             }
#             pycb += "\n"
#             pycb += py_callback_name+"({'name':__colomoto_upload_name, 'content': __colomoto_upload_content})\n";
#             pycb += "del __colomoto_upload_name, __colomoto_upload_content"
#
#             IPython.notebook.kernel.execute(pycb, {iopub: {output: callback}});
#         };
#     })(f);
#     reader.readAsDataURL(f);
# }
#
# function resolve_function(tool_api, funcname) {
#     if (tool_api.hasOwnProperty(funcname)) {
#         return tool_api[funcname];
#     } else {
#         return window[funcname];
#     }
# }
#
# function colomoto_extension(Jupyter, ssid, name, menu, toolbar, tool_api) {
#
#     function insert_snippet_code(snippet) {
#         var cell = Jupyter.notebook.get_selected_cell();
#         Jupyter.notebook.edit_mode();
#         cell.code_mirror.replaceSelection(snippet, 'around');
#         //cell.focus_editor();
#     }
#
#     /**
#         from https://github.com/moble/jupyter_boilerplate/blob/master/main.js
#     */
#     function callback_insert_snippet (evt) {
#         // this (or event.currentTarget, see below) always refers to the DOM
#         // element the listener was attached to - see
#         // http://stackoverflow.com/questions/12077859
#         insert_snippet_code($(evt.currentTarget).data('snippet-code'));
#     }
#     function build_menu_element (menu_item_spec, direction) {
#         // Create the menu item html element
#         var element = $('<li/>');
#
#         if (typeof menu_item_spec == 'string') {
#             if (menu_item_spec != '---') {
#                 return element.html(menu_item_spec)
#                         .addClass('ui-state-disabled')
#                         .attr({"style": "padding:2px .4em"})
#                        ;
#             }
#             return element.addClass('divider');
#         }
#
#         var a = $('<a/>')
#             .attr('href', '#')
#             .html(menu_item_spec.name)
#             .appendTo(element);
#         if (menu_item_spec.hasOwnProperty('snippet')) {
#             var snippet = menu_item_spec.snippet;
#             if (typeof snippet == 'string' || snippet instanceof String) {
#                 snippet = [snippet];
#             }
#             a.attr({
#                 'title' : "", // Do not remove this, even though it's empty!
#                 'data-snippet-code' : snippet.join('\n'),
#             })
#             .on('click', callback_insert_snippet)
#             .addClass('snippet');
#         }
#         else if (menu_item_spec.hasOwnProperty('internal-link')) {
#             a.attr('href', menu_item_spec['internal-link']);
#         }
#         else if (menu_item_spec.hasOwnProperty('external-link')) {
#             a.empty();
#             a.attr('href', menu_item_spec['external-link']);
#             a.attr({
#                 'target' : '_blank',
#                 'title' : 'Opens in a new window',
#             });
#             $('<i class="fa fa-external-link menu-icon pull-right"/>').appendTo(a);
#             $('<span/>').html(menu_item_spec.name).appendTo(a);
#         }
#
#         if (menu_item_spec.hasOwnProperty('sub-menu')) {
#             element
#                 .addClass('dropdown-submenu')
#                 .toggleClass('dropdown-submenu-left', direction === 'left');
#             var sub_element = $('<ul class="dropdown-menu"/>')
#                 .toggleClass('dropdown-menu-compact', menu_item_spec.overlay === true) // For space-saving menus
#                 .appendTo(element);
#
#             var new_direction = (menu_item_spec['sub-menu-direction'] === 'left') ? 'left' : 'right';
#             for (var j=0; j<menu_item_spec['sub-menu'].length; ++j) {
#                 var sub_menu_item_spec = build_menu_element(menu_item_spec['sub-menu'][j], new_direction);
#                 if(sub_menu_item_spec !== null) {
#                     sub_menu_item_spec.appendTo(sub_element);
#                 }
#             }
#         }
#
#         return element;
#     }
#
#     function menu_setup (menu_item_specs, sibling, insert_before_sibling) {
#         for (var i=0; i<menu_item_specs.length; ++i) {
#             var menu_item_spec;
#             if (insert_before_sibling) {
#                 menu_item_spec = menu_item_specs[i];
#             } else {
#                 menu_item_spec = menu_item_specs[menu_item_specs.length-1-i];
#             }
#             var direction = (menu_item_spec['menu-direction'] == 'left') ? 'left' : 'right';
#             var menu_element = build_menu_element(menu_item_spec, direction);
#             // We need special properties if this item is in the navbar
#             if ($(sibling).parent().is('ul
# <script type="text/javascript" id="colomoto-setup-1896924" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var mymodule_jsapi = {  };
#     colomoto_extension(Jupyter, "colomoto-setup-1896924", "mymodule", {"name": "MaBoSS", "sub-menu": [{"name": "Load MaBoSS file", "snippet": ["masim = maboss.load(\"filename.bnd\", \"filename.cfg\")"]}, {"name": "Network", "sub-menu": [{"name": "Set istate", "snippet": ["maboss.wg_set_istate(masim)"]}, {"name": "Get initial state", "snippet": ["masim.get_initial_state()"]}]}, {"name": "Simulation", "sub-menu": [{"name": "Create mutant", "snippet": ["maboss.wg_make_mutant(masim)"]}, {"name": "Run", "snippet": ["simres = masim.run()"]}, {"name": "Set initial states", "snippet": ["masim.network.set_istate([\"mygenelist\"],{})"]}, {"name": "Set output", "snippet": ["maboss.wg_set_output(masim)"]}]}, {"name": "Results", "sub-menu": [{"name": "Save results", "snippet": ["simres.save(\"filename\")"]}, {"name": "Plot piechart", "snippet": ["simres.plot_piechart()"]}, {"name": "Plot trajectory", "snippet": ["simres.plot_trajectory()"]}]}, {"name": "Conversion", "sub-menu": [{"name": "Convert to biolqm", "snippet": ["biolqm_model = maboss.to_biolqm(masim)"]}, {"name": "Convert to minibn", "snippet": ["minibn_model = maboss.to_minibn(masim)"]}]}, "---", {"name": "Documentation", "external-link": "http://pymaboss.readthedocs.io"}]}, null, mymodule_jsapi);
#      }</script><style type="text/css">
#     #mymodule_menu {
#         color: green;
#         background-color: white;
#     }
#     </style>
# <script type="text/javascript" id="colomoto-setup-4377802" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var biolqm_jsapi = { action_upload_model: function() {
#         var cell = Jupyter.notebook.get_selected_cell();
#         cell.set_text('lqm = '+biolqm_jsapi.module_alias+'.upload()');
#         cell.focus_editor();
#     } };
#     colomoto_extension(Jupyter, "colomoto-setup-4377802", "biolqm", {"name": "bioLQM", "sub-menu": [{"name": "Upload model", "snippet": ["lqm = biolqm.upload()"]}, {"name": "Load model", "snippet": ["lqm = biolqm.load(\"model.sbml\")"]}, "---", {"name": "Export to file", "sub-menu": [{"name": "SBML-qual v1.0 (.sbml)", "snippet": ["biolqm.save(lqm, \"mymodel.sbml\", \"sbml\")"]}, "Functions formats", {"name": "BoolNet (.bnet)", "snippet": ["biolqm.save(lqm, \"mymodel.bnet\", \"bnet\")"]}, {"name": "BooleanNet (.booleannet)", "snippet": ["biolqm.save(lqm, \"mymodel.booleannet\", \"booleannet\")"]}, {"name": "BoolSim (.boolsim)", "snippet": ["biolqm.save(lqm, \"mymodel.boolsim\", \"boolsim\")"]}, {"name": "Raw Boolean functions (.boolfunctions)", "snippet": ["biolqm.save(lqm, \"mymodel.boolfunctions\", \"boolfunctions\")"]}, {"name": "Truth table (.tt)", "snippet": ["biolqm.save(lqm, \"mymodel.tt\", \"tt\")"]}, "Petri net formats", {"name": "APNN (.apnn)", "snippet": ["biolqm.save(lqm, \"mymodel.apnn\", \"apnn\")"]}, {"name": "INA (.ina)", "snippet": ["biolqm.save(lqm, \"mymodel.ina\", \"ina\")"]}, {"name": "PNML (.pnml)", "snippet": ["biolqm.save(lqm, \"mymodel.pnml\", \"pnml\")"]}, "Dedicated formats", {"name": "GINML (.ginml)", "snippet": ["biolqm.save(lqm, \"mymodel.ginml\", \"ginml\")"]}, {"name": "GNA non-xml (.gna)", "snippet": ["biolqm.save(lqm, \"mymodel.gna\", \"gna\")"]}, {"name": "MaBoSS (.bnd)", "snippet": ["biolqm.save(lqm, \"mymodel.bnd\", \"bnd\")"]}, {"name": "Pint (.an)", "snippet": ["biolqm.save(lqm, \"mymodel.an\", \"an\")"]}]}, {"name": "Convert to tool", "sub-menu": [{"name": "GINsim", "snippet": ["lrg = biolqm.to_ginsim(lqm)"]}, {"name": "MaBoSS", "snippet": ["masim = biolqm.to_maboss(lqm)"]}, {"name": "Pint", "snippet": ["an = biolqm.to_pint(lqm)"]}]}, "---", {"name": "Compute fixpoints", "snippet": ["fps = biolqm.fixpoints(lqm)"]}, {"name": "Compute trap spaces", "snippet": ["traps = biolqm.trapspace(lqm)"]}, "---", {"name": "Model modifications", "sub-menu": [{"name": "Perturbation", "snippet": ["lqm_mod = biolqm.perturbation(lqm, \"node%0\")"]}, {"name": "Booleanization", "snippet": ["lqm_bool = biolqm.booleanize(lqm)"]}, {"name": "Reduction", "snippet": ["lqm_red = biolqm.reduce(lqm, \"fixed,output,duplicate\")"]}, {"name": "Reversal", "snippet": ["lqm_rev = biolqm.reverse(lqm)"]}, {"name": "Sanitize", "snippet": ["lqm_san = biolqm.sanitize(lqm)"]}]}, "---", {"name": "Documentation", "external-link": "http://ginsim.naldi.info/biolqm/site/doc/index.html"}]}, [{"name": "upload", "setup": {"icon": "fa-upload", "help": "Upload model", "handler": "action_upload_model"}}], biolqm_jsapi);
#      }</script><style type="text/css">
#     #biolqm_menu {
#         color: #00007f;
#         background-color: white;
#     }
#
#     div#biolqm-toolbar:before {
#         content: "bioLQM";
#         float: left;
#         margin-left: 1em;
#         margin-right: 1em;
#         margin-top: 0.2em;
#     }
#     div#biolqm-toolbar,
#     div#biolqm-toolbar button {
#         color: #00007f;
#     }
#     </style>
# <script type="text/javascript" id="colomoto-setup-9815024" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
#     var ginsim_jsapi = { action_upload_model: function() {
#         var cell = Jupyter.notebook.get_selected_cell();
#         cell.set_text('lrg = '+ginsim_jsapi.module_alias+'.upload()');
#         cell.focus_editor();
#     } };
#     colomoto_extension(Jupyter, "colomoto-setup-9815024", "ginsim", {"name": "GINsim", "sub-menu": [{"name": "Upload model", "snippet": ["lrg = ginsim.upload()"]}, {"name": "Load model", "snippet": ["lrg = ginsim.load(\"model.zginml\")"]}, "---", {"name": "Export to file", "sub-menu": [{"name": "MaBoSS (.bnd, .cfg)", "snippet": ["ginsim.service(\"maboss\").export(lrg, \"mymodel.bnd\")"]}]}, {"name": "Convert to tool", "sub-menu": [{"name": "bioLQM", "snippet": ["lqm = ginsim.to_biolqm(lrg)"]}, {"name": "MaBoSS", "snippet": ["masim = ginsim.to_maboss(lrg)"]}, {"name": "NuSMV", "snippet": ["smv = ginsim.to_nusmv(lrg)"]}, {"name": "Pint", "snippet": ["an = ginsim.to_pint(lrg)"]}]}, "---", {"name": " Display regulatory graph", "snippet": ["ginsim.show(lrg)"]}]}, [{"name": "upload", "setup": {"icon": "fa-upload", "help": "Upload model", "handler": "action_upload_model"}}], ginsim_jsapi);
#      }</script><style type="text/css">
#     #ginsim_menu {
#         color: blue;
#         background-color: white;
#     }
#
#     div#ginsim-toolbar:before {
#         content: "GINsim";
#         float: left;
#         margin-left: 1em;
#         margin-right: 1em;
#         margin-top: 0.2em;
#     }
#     div#ginsim-toolbar,
#     div#ginsim-toolbar button {
#         color: blue;
#     }
#     </style>

# %%
# create directory where the models and results will be saved

type_models = 'genes_models'

src_dir_generic_models = f'models/prostate/generic/{type_models}'
folder_generic_models = f'validation/prostate/{type_models}/generic_models'
# folder_generic_models_bnd = f'validation/prostate/{type_models}/generic_models'
folder_pers_models = f'validation/prostate/{type_models}/personalized_models'

folder_save_results = f"validation/prostate/{type_models}/results/phenotype_distribution/phenotype_table"
dest_base_dir = f"validation/prostate/{type_models}/results/phenotype_group_means"

directories = [
    Path(src_dir_generic_models).parent,
    Path(folder_generic_models),
    Path(folder_pers_models),
    Path(folder_save_results),
    Path(dest_base_dir),
]

# Create them
for directory in directories:
    directory.mkdir(parents=True, exist_ok=True)



# copy the generic model from the models to validation generic models
for filename in os.listdir(src_dir_generic_models):
    src_file = os.path.join(src_dir_generic_models, filename)
    dst_file = os.path.join(folder_generic_models, filename)
    if os.path.isfile(src_file):
        shutil.copy(src_file, dst_file)

# %%
tissue = 'Prostate'

# for the model
phenotype_interest = ["Proliferation","Invasion","DNA_Repair","Migration","Apoptosis"]

# %%
# Import data
phenotype_data = pd.read_csv('data/TCGA_data/prostate/TCGA_PRAD_phenotypes.csv')
genes_data = pd.read_csv('data/TCGA_data/prostate/TCGA_PRAD_genes_illumina.csv', sep='\t')
cnv_data = pd.read_csv('data/TCGA_data/prostate/TCGA_PRAD_cnv_gistic2.csv',sep='\t')
genes_synonyms = pd.read_csv("data/e_ensembl/genes_synonyms.csv", delimiter="\t")
uniprot_data = pd.read_csv("data/uniprot/uniprot_map.csv")

# keep all montagud nodes
montagud_data = (
    pd.read_csv('data/Montagud_inter_nodes_data.csv', header=1)
    .loc[:, ['Target node', 'Interaction type', 'Source']])

# Create list of genes of interest (in Montagud data)
montagud_nodes = list(set(montagud_data['Target node'].tolist() + montagud_data['Source'].tolist()))
montagud_nodes = [node for node in montagud_nodes if node != '0/1']
montagud_nodes = [node.upper() for node in montagud_nodes if isinstance(node, str)]
# montagud_nodes.append('KRAS')
# to_remove = ['RAS', 'FUSED_EVENT', 'NKX3_1', 'SPOP', 'AR_ERG']

# montagud_nodes = [node for node in montagud_nodes if node not in to_remove]
# montagud_nodes = list(set(montagud_nodes))

# %%
# changes montagud nodes according to modif done in the cfg/ bnd files

montagud_nodes = ['CASP8' if x == 'CASPASE8' else x for x in montagud_nodes]
montagud_nodes = ['CASP3' if x == 'CASPASE3' else x for x in montagud_nodes]
montagud_nodes = ['CASP9' if x == 'CASPASE9' else x for x in montagud_nodes]


montagud_nodes = ['CCNB1' if x == 'CYCLINB' else x for x in montagud_nodes]
montagud_nodes = ['CCND1' if x == 'CYCLIND' else x for x in montagud_nodes]


montagud_nodes = ['DVL1' if x == 'DSH' else x for x in montagud_nodes]

montagud_nodes = ['CTNNB1' if x == 'BETA_CATENIN' else x for x in montagud_nodes]

montagud_nodes = ['CDH1' if x == 'E_CADHERIN' else x for x in montagud_nodes]
montagud_nodes = ['CYCS' if x == 'CYCC' else x for x in montagud_nodes]

montagud_nodes = ['MEK1' if x == 'MEK1_2' else x for x in montagud_nodes]
montagud_nodes = ['NFKB' if x == 'NFK_B' else x for x in montagud_nodes]
montagud_nodes = ['SNAI1' if x == 'SNAIL' else x for x in montagud_nodes]
montagud_nodes = ['TNF' if x == 'TNFALPHA' else x for x in montagud_nodes]
montagud_nodes = ['TSC1' if x == 'TSC1_2' else x for x in montagud_nodes]
montagud_nodes = ['BCL2L1' if x == 'BCL_XL' else x for x in montagud_nodes]
montagud_nodes = ['MAP3K1' if x == 'MAP3K1_3' else x for x in montagud_nodes]
montagud_nodes = ['CHK1' if x == 'CHK1_2' else x for x in montagud_nodes]




montagud_nodes.append('MEK2')
montagud_nodes.append('TSC2')
montagud_nodes.append('MAP3K3')
montagud_nodes.append('CHK2')

# %%
# stratify by gleason score

phenotype_data_filtered = phenotype_data[['sampleID','gleason_score']]

# %%
# create 3 groups: gleason score of 6, gleason score of 7, and of gleason score of > 8

group_0 = [6]
group_1 = [7]
group_2 = [8, 9, 10]

conditions = [
phenotype_data_filtered["gleason_score"].isin(group_0),
phenotype_data_filtered["gleason_score"].isin(group_1),
phenotype_data_filtered["gleason_score"].isin(group_2),

]
choices = ['low_aggressive', 'middle_aggressive', 'high_aggressive']

phenotype_data_filtered.loc[:, "Gleason_group"] = np.select(
conditions, choices, default=""
)

sampled_df = phenotype_data_filtered.groupby("Gleason_group", group_keys=False).apply(
    lambda x: x.sample(n=min(len(x), 30), random_state=42)
)
patients_id = list(sampled_df['sampleID'])
# Out:
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_4268/3296898739.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phenotype_data_filtered.loc[:, "Gleason_group"] = np.select(
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_4268/3296898739.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = phenotype_data_filtered.groupby("Gleason_group", group_keys=False).apply(

# %%
# pre-process CNV data

cnv_data_col = list(cnv_data.columns)
common_col = list(set(cnv_data_col) & set(patients_id))
col_keep = ['Gene Symbol'] + common_col
cnv_data_filtered = cnv_data[col_keep]


df_melted_cnv = cnv_data_filtered.melt(
    id_vars=["Gene Symbol"],       # columns to keep fixed
    var_name="samples_id",         # name for the variable column (sample IDs)
    value_name="expression_value"  # name for the values
)


df_melted_cnv['Gene Symbol'] = df_melted_cnv['Gene Symbol'].str.split('|').str[0] 

df_melted_cnv = df_melted_cnv.rename(
    columns={
        "samples_id": "model_id",
        "Gene Symbol": "gene_symbol",
        "expression_value": "rsem_tpm",
    }
)
group_loss = [-1, -2]
group_normal = [0]
group_gain = [1, 2]

conditions = [
    df_melted_cnv["rsem_tpm"].isin(group_loss),
    df_melted_cnv["rsem_tpm"].isin(group_normal),
    df_melted_cnv["rsem_tpm"].isin(group_gain),
]
choices = ["Loss", "Normal", "Gain"]
df_melted_cnv.loc[:, "effect"] = np.select(conditions, choices, default="")

df_melted_cnv = df_melted_cnv[df_melted_cnv['gene_symbol'].isin(montagud_nodes)]
df_melted_cnv.to_csv('data/TCGA_data/prostate/filtered_data/cnv_samples_table.csv')

# %%
df_genes_copy= genes_data.copy()
genes_synonyms_df = identify_genes_synonyms(genes_synonyms, uniprot_data, montagud_nodes)
print(genes_synonyms_df.head())

# then replace genes names by montagud nodes
# Out:
#   Gene name_x Gene Synonym montagud_node
# 0        BMP2        BMP2A          BMP2
# 1       NCOA3         ACTR         NCOA3
# 2       NCOA3         ACTR         NCOA3
# 3       NCOA3         AIB1         NCOA3
# 4       NCOA3         AIB1         NCOA3
# /Users/romane/repos/icr/Attractor-Resistance/pre_process_data/pre_process_genes.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_synonyms["Gene name"] = data_synonyms["Gene name"].str.upper()
# /Users/romane/repos/icr/Attractor-Resistance/pre_process_data/pre_process_genes.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_synonyms["Gene Synonym"] = data_synonyms["Gene Synonym"].str.upper()

# %%
# pre-process genes data

genes_data_col = list(genes_data.columns)
common_col = list(set(genes_data_col) & set(patients_id))
col_keep = ['sample'] + common_col
genes_data_filtered = genes_data[col_keep]


df_melted_gene = genes_data_filtered.melt(
    id_vars=["sample"],       # columns to keep fixed
    var_name="samples_id",         # name for the variable column (sample IDs)
    value_name="expression_value"  # name for the values
)

df_melted_gene['sample'] = df_melted_gene['sample'].str.split('|').str[0] 

df_melted_gene = df_melted_gene.rename(
    columns={
        "samples_id": "model_id",
        "sample": "gene_symbol",
        "expression_value": "rsem_tpm",
    }
)
df_melted_gene['gene_symbol'] = df_melted_gene['gene_symbol'].str.upper()
df_melted_gene['gene_symbol'] = df_melted_gene['gene_symbol'].str.replace('_', '', regex=False)

# %%
df_melted_gene_copy = df_melted_gene.copy()
print(df_melted_gene_copy.head())
# Out:
#   gene_symbol         model_id  rsem_tpm
# 0   ARHGEF10L  TCGA-YL-A9WH-01    8.7340
# 1       HIF3A  TCGA-YL-A9WH-01    4.0102
# 2       RNF17  TCGA-YL-A9WH-01    0.0000
# 3       RNF10  TCGA-YL-A9WH-01   12.3159
# 4       RNF11  TCGA-YL-A9WH-01   10.4304

# %%
melted = genes_synonyms_df.melt(
    id_vars='montagud_node',
    value_vars=['Gene name_x', 'Gene Synonym'],
    value_name='gene'
)[['gene', 'montagud_node']].drop_duplicates()


print(melted)
mapping_dict = dict(zip(melted['gene'], melted['montagud_node']))

df_melted_gene['gene_symbol'] = df_melted_gene['gene_symbol'].map(mapping_dict).fillna(df_melted_gene['gene_symbol'])
# Out:
#           gene montagud_node
# 0         BMP2          BMP2
# 1        NCOA3         NCOA3
# 111      MAPK1           ERK
# 115       CDH2          CDH2
# 181      AXIN1         AXIN1
# ...        ...           ...
# 19969     CJUN           JUN
# 19974    APAF3         CASP9
# 19976  ICELAP6         CASP9
# 19978     MCH6         CASP9
# 19980  PPP1R56         CASP9
#
# [376 rows x 2 columns]

# %%
print(df_melted_gene_copy[df_melted_gene_copy['gene_symbol'] != df_melted_gene['gene_symbol']])
# Out:
#         gene_symbol         model_id  rsem_tpm
# 60             OPA1  TCGA-YL-A9WH-01   10.7861
# 106          MRPL28  TCGA-YL-A9WH-01   10.2733
# 573            RAC3  TCGA-YL-A9WH-01    9.0444
# 1892         PRKAA2  TCGA-YL-A9WH-01    8.3485
# 2326        SLC22A3  TCGA-YL-A9WH-01    6.3459
# ...             ...              ...       ...
# 1804658        EZH1  TCGA-YL-A8S8-01    9.6834
# 1804885       EPHB2  TCGA-YL-A8S8-01    8.6746
# 1806228      AKR1B1  TCGA-YL-A8S8-01    8.8926
# 1806392        FZR1  TCGA-YL-A8S8-01    9.9405
# 1806529      TCEAL1  TCGA-YL-A8S8-01    8.7856
#
# [4400 rows x 3 columns]

# %%
df_melted_gene = df_melted_gene[df_melted_gene['gene_symbol'].isin(montagud_nodes)]

df_melted_gene.to_csv('data/TCGA_data/prostate/filtered_data/genes_samples_table.csv')

# %%
# read the pre-processed data
df_melted_cnv= pd.read_csv('data/TCGA_data/prostate/filtered_data/cnv_samples_table.csv')
df_melted_gene= pd.read_csv('data/TCGA_data/prostate/filtered_data/genes_samples_table.csv')

# %%
 # Create generic models 
folder_generic_models_cfg = f'{folder_generic_models}/Montagud2022_Prostate_Cancer.cfg'
folder_generic_models_bnd = f'{folder_generic_models}/Montagud2022_Prostate_Cancer.bnd'

create_generic_patients_cfg_bnd_validation(folder_generic_models_cfg, folder_generic_models_bnd, folder_pers_models, patients_id, tissue)
# Out:
# All .cfg and .bnd files created for the validation.

# %%
# update phenotypes in generic models 
generic_models_update_phenotypes(phenotype_interest, folder_pers_models, folder_pers_models)
# Out:
# Updated EEF2K.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated LDHA.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated VHL.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated GADD45.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated CDH2.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated PI3K.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated FGF.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Updated RB1.is_internal=1 in TCGA-ZG-A9L5-01_Prostate.cfg
# Upd
is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated Proliferation.is_internal=0 in TCGA-HC-7079-01_Prostate.cfg
# Updated ERK.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated CHK1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated GSK3.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated IKK.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated SNAI1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated GLI.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated AMP_ATP.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated EEF2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated ROS.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated TGFB.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated TNF.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated P70S6KAB.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated P53.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated BCL2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated MAP3K1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated E2F1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated NKX31.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated P15.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated ETS1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated BRCA2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated Lactic_acid.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated Androgen.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated NCOR1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated BAK.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated RAS.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated MEK1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated TSC1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated AMPK.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated NFKB.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated P90RSK.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated DAXX.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated SMO.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated HSPS.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated EMT.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated AR.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated BRCA1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated FOS.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated YWHAZ.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated MYC_MAX.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated EGFR.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated COX4I2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated AR_ERG.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated TERT.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated CCND1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated APAF1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated CHK2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated SMAD.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated AXIN1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated SLUG.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated HIF1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated ETV1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated BAX.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated FADD.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated NCOR2.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated FOXA1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated Metastasis.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated DVL1.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Updated TGFBR.is_internal=1 in TCGA-HC-7079-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-7079-01_Prostate.cfg

# %%
# personalize the boolean networks with genes 
table_rna_seq_patients = create_table_rna_seq_patients(df_melted_gene)
print(table_rna_seq_patients.head())
# Out:
# gene_expression_level                               High Gene Expression  \
# model_id
# TCGA-2A-A8VL-01        CDH1, EEF2K, EMT, FOS, JUN, NCOA3, P15, P21, P...
# TCGA-2A-AAYO-01              BAX, CASP9, E2F1, EMT, MEK1, P15, P38, TERT
# TCGA-2A-AAYU-01                BAX, CDH1, EMT, ERG, ERK, P15, PDK1, SPOP
# TCGA-CH-5738-01        APAF1, ATM, CFLAR, CTNNB1, EMT, ERK, FOS, GADD...
# TCGA-CH-5743-01        APAF1, ATM, ATR, BCL2, BMP2, BRCA2, CASP3, CCN...
#
# gene_expression_level                                Low Gene Expression
# model_id
# TCGA-2A-A8VL-01        BIRC5, BRCA1, BRCA2, CHK2, E2F1, EMT, ERK, EZH...
# TCGA-2A-AAYO-01         AR, ATR, CDH1, E2F1, EGFR, NCOR2, P15, P38, VEGF
# TCGA-2A-AAYU-01        AR, BCL2, BMP2, CCND1, DAXX, E2F1, EEF2K, EMT,...
# TCGA-CH-5738-01        AXIN1, BAD, CCND1, CDH1, CDH2, DAXX, FADD, MEK...
# TCGA-CH-5743-01        AKT, AXIN1, BAD, DVL1, EEF2, ERK, EZH2, FADD, ...
# /Users/romane/repos/icr/Attractor-Resistance/pre_process_data/pre_process_genes.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rna_seq_data.rename(columns={"gene_symbol": "gene_name"}, inplace=True)

# %%
personalized_patients_genes_cfgs(df_melted_gene,montagud_nodes,folder_pers_models,folder_pers_models,patients_id,table_rna_seq_patients,tissue)
# Out:
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-ZG-A9L5-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-QU-A6IO-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-J4-AATV-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-A7NN-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9-7519-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-VP-A87D-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9-6343-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-8472-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-CH-5743-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-KK-A8I9-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-A9TH-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-YL-A9WI-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-YL-A8SF-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-Y6-A8TL-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-VN-A88Q-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-V1-A8MF-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-XJ-A9DX-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-YL-A8S8-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-7748-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-7738-11_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-AB27-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-5516-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-CH-5768-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9-6342-11_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-AB20-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-CH-5748-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-5498-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-J4-A83N-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-8213-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HI-7170-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-V1-A9ZR-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-7797-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-7736-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-7312-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-V1-A9ZK-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-HC-8258-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-EJ-A46I-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9-6347-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-VP-A872-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-V1-A9OT-01_Prostate.cfg
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9-6329-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-2A-AAYU-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-J4-AAU2-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-KK-A6E5-01_Prostate.bnd
# Modified and saved: validation/prostate/genes_models/personalized_models/TCGA-G9

# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: RB1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: FOXA1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: FOS
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: AXIN1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: TSC2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: EEF2K
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: CDH1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: NCOR1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: NF1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BRCA1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: SPOP
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: MAP3K3
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BIRC5
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: CDH2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BCL2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: EEF2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BAX
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BMP2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: COX4I2
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: BCL2L1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: E2F1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: NCOA3
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: SNAI1
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: ERG
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: EP300
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: AR
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# AR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WH-01, gene: MED12
# Patient TCGA-YL-A9WH-01 is in both gain and loss groups. Please review.
# MED12 node found. Replacing...
# TCGA-YL-A9WH-01: CNV — nodes modified
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: DVL1
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CASP9
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ZBTB17
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: PDK1
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CFLAR
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CASP8
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CTNNB1
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EGF
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CASP3
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MAP3K1
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CCNB1
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: TNF
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: RUNX2
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: TWIST1
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: RHEB
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: SHH
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: YWHAZ
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: TSC1
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MXI1
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: LDHA
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BAD
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CCND1
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: FADD
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ETS1
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: FRS2
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: APAF1
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: FOS
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: TSC2
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EEF2K
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CDH1
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MAP3K3
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BIRC5
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: CDH2
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EEF2
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BMP2
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: COX4I2
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: BCL2L1
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: E2F1
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: NCOA3
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: SNAI1
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A9WL-01, gene: MED12
# MED12 node found. Replacing...
# TCGA-YL-A9WL-01: CNV — nodes modified
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: DVL1
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CASP9
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ZBTB17
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: PDK1
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CFLAR
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CASP8
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CTNNB1
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EGF
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CASP3
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MAP3K1
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CCNB1
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: TNF
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: RUNX2
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: TWIST1
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: RHEB
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: SHH
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: YWHAZ
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: TSC1
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MXI1
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: LDHA
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BAD
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CCND1
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: FADD
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ETS1
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: FRS2
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: APAF1
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: FOS
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: TSC2
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EEF2K
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CDH1
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MAP3K3
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BIRC5
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: CDH2
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EEF2
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BMP2
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: COX4I2
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: BCL2L1
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: E2F1
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: NCOA3
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: SNAI1
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient TCGA-VN-A88Q-01, gene: MED12
# MED12 node found. Replacing...
# TCGA-VN-A88Q-01: CNV — nodes modified
# 🔍 Processing patient TCGA-HC-7821-01, gene: DVL1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CASP9
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ZBTB17
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: JUN
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: PDK1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CFLAR
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CASP8
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: IDH1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: VHL
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CTNNB1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ATR
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: FGFR3
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EGF
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CASP3
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: TERT
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MAP3K1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CCNB1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: TNF
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: DAXX
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: RUNX2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ETV1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: TWIST1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EGFR
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: SMO
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EZH2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: RHEB
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: SHH
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: YWHAZ
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MYC
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: PTCH1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: TSC1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: PTEN
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MXI1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: LDHA
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BAD
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CCND1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: FADD
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ATM
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ETS1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MDM2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: FRS2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: APAF1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: NCOR2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BRCA2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: RB1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: FOXA1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: FOS
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: AXIN1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: TSC2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EEF2K
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CDH1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: NCOR1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: NF1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BRCA1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: SPOP
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MAP3K3
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BIRC5
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: CDH2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BCL2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EEF2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BAX
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BMP2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: COX4I2
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: BCL2L1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: E2F1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: NCOA3
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: SNAI1
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: ERG
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: EP300
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: AR
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# AR node found. Replacing...
# 🔍 Processing patient TCGA-HC-7821-01, gene: MED12
# Patient TCGA-HC-7821-01 is in both gain and loss groups. Please review.
# MED12 node found. Replacing...
# TCGA-HC-7821-01: CNV — nodes modified
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: DVL1
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CASP9
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ZBTB17
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: PDK1
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CFLAR
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CASP8
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CTNNB1
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EGF
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CASP3
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MAP3K1
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CCNB1
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: TNF
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: RUNX2
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: TWIST1
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: RHEB
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: SHH
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: YWHAZ
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: TSC1
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MXI1
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: LDHA
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BAD
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CCND1
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: FADD
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ETS1
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: FRS2
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: APAF1
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: FOS
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: TSC2
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EEF2K
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CDH1
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MAP3K3
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BIRC5
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: CDH2
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EEF2
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BMP2
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: COX4I2
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: BCL2L1
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: E2F1
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: NCOA3
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: SNAI1
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient TCGA-EJ-AB20-01, gene: MED12
# MED12 node found. Replacing...
# TCGA-EJ-AB20-01: CNV — nodes modified
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: DVL1
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CASP9
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ZBTB17
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: JUN
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: PDK1
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CFLAR
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CASP8
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CTNNB1
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EGF
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CASP3
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MAP3K1
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CCNB1
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: TNF
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: RUNX2
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: TWIST1
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: RHEB
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: SHH
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: YWHAZ
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: TSC1
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MXI1
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: LDHA
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BAD
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CCND1
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: FADD
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ETS1
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: FRS2
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: APAF1
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: FOS
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: TSC2
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EEF2K
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CDH1
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MAP3K3
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BIRC5
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: CDH2
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EEF2
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BMP2
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: COX4I2
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: BCL2L1
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: E2F1
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: NCOA3
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: SNAI1
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient TCGA-2A-AAYU-01, gene: MED12
# MED12 node found. Replacing...
# TCGA-2A-AAYU-01: CNV — nodes modified
# 🔍 Processing patient TCGA-CH-5788-01, gene: DVL1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CASP9
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: ZBTB17
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: JUN
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: PDK1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CFLAR
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CASP8
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: IDH1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: VHL
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CTNNB1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: ATR
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: FGFR3
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: EGF
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CASP3
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: TERT
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: MAP3K1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: CCNB1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: TNF
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: DAXX
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: RUNX2
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: ETV1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: TWIST1
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: EGFR
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-CH-5788-01, gene: SMO
# Patient TCGA-CH-5788-01 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# ...
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: IDH1
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: VHL
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CTNNB1
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: ATR
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: FGFR3
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EGF
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CASP3
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: TERT
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MAP3K1
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CCNB1
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: TNF
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: DAXX
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: RUNX2
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: ETV1
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: TWIST1
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EGFR
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: SMO
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EZH2
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: RHEB
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: SHH
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: YWHAZ
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MYC
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: PTCH1
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: TSC1
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: PTEN
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MXI1
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: LDHA
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BAD
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CCND1
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: FADD
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: ATM
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: ETS1
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MDM2
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: FRS2
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: APAF1
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: NCOR2
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BRCA2
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: RB1
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: FOXA1
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: FOS
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: AXIN1
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: TSC2
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EEF2K
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CDH1
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: NCOR1
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: NF1
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BRCA1
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: SPOP
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MAP3K3
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BIRC5
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: CDH2
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BCL2
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EEF2
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BAX
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BMP2
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: COX4I2
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: BCL2L1
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: E2F1
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: NCOA3
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: SNAI1
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: ERG
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: EP300
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: AR
# AR node found. Replacing...
# 🔍 Processing patient TCGA-KC-A7FE-01, gene: MED12
# MED12 node found. Replacing...
# TCGA-KC-A7FE-01: CNV — nodes modified
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: DVL1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# DVL1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CASP9
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CASP9 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ZBTB17
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ZBTB17 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: JUN
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# JUN node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: PDK1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# PDK1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CFLAR
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CFLAR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CASP8
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CASP8 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: IDH1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# IDH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: VHL
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# VHL node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CTNNB1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CTNNB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ATR
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ATR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: FGFR3
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# FGFR3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EGF
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EGF node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CASP3
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CASP3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: TERT
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# TERT node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MAP3K1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MAP3K1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CCNB1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CCNB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: TNF
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# TNF node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: DAXX
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# DAXX node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: RUNX2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# RUNX2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ETV1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ETV1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: TWIST1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# TWIST1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EGFR
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EGFR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: SMO
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# SMO node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EZH2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EZH2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: RHEB
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# RHEB node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: SHH
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# SHH node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: YWHAZ
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# YWHAZ node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MYC
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MYC node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: PTCH1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# PTCH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: TSC1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# TSC1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: PTEN
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# PTEN node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MXI1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MXI1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: LDHA
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# LDHA node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BAD
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BAD node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CCND1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CCND1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: FADD
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# FADD node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ATM
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ATM node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ETS1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ETS1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MDM2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MDM2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: FRS2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# FRS2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: APAF1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# APAF1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: NCOR2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# NCOR2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BRCA2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BRCA2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: RB1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# RB1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: FOXA1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# FOXA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: FOS
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# FOS node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: AXIN1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# AXIN1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: TSC2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# TSC2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EEF2K
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EEF2K node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CDH1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CDH1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: NCOR1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# NCOR1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: NF1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# NF1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BRCA1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BRCA1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: SPOP
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# SPOP node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MAP3K3
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MAP3K3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BIRC5
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BIRC5 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: CDH2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# CDH2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BCL2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BCL2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EEF2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EEF2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BAX
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BAX node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BMP2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BMP2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: COX4I2
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# COX4I2 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: BCL2L1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# BCL2L1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: E2F1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# E2F1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: NCOA3
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# NCOA3 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: SNAI1
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# SNAI1 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: ERG
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# ERG node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: EP300
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# EP300 node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: AR
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# AR node found. Replacing...
# 🔍 Processing patient TCGA-YL-A8S8-01, gene: MED12
# Patient TCGA-YL-A8S8-01 is in both gain and loss groups. Please review.
# MED12 node found. Replacing...
# TCGA-YL-A8S8-01: CNV — nodes modified

# %%
# Compute phenotype distribution for each patient
# folder_models = 'validation/prostate/personalized_models'
# folder_save_results = 'validation/prostate/results/phenotype_distribution/phenotype_table'

phenotypes_interest = [
        "Proliferation",
        "Invasion",
        "DNA_Repair",
        "Migration",
        "Apoptosis",
    ]

inputs_list = ['EGF', 'FGF', 'TGFB', 'Androgen', 'Hypoxia', 'Nutrients', 'Carcinogen', 'Acidosis', 'TNF', 'fused_event', 'SPOP']
for patient  in patients_id:
    compute_phenotype_table(folder_save_results, folder_pers_models, patient, inputs_list, phenotypes_interest, tissue= 'Prostate')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 15
#      13 inputs_list = ['EGF', 'FGF', 'TGFB', 'Androgen', 'Hypoxia', 'Nutrients', 'Carcinogen', 'Acidosis', 'TNF', 'fused_event', 'SPOP']
#      14 for patient  in patients_id:
# ---> 15     compute_phenotype_table(folder_save_results, folder_pers_models, patient, inputs_list, phenotypes_interest, tissue= 'Prostate')
#
# File ~/repos/icr/Attractor-Resistance/MaBoSS_simulation/maboss_phenotype_patient.py:41, in compute_phenotype_table(folder_save_results, folder_models, patient_id, input_nodes, phenotypes_interest, tissue)
#      37 while not converged and current_max_time < max_time_limit:
#      38     model_pers_lung.update_parameters(
#      39         time_tick=0.1, max_time=current_max_time, sample_count=500
#      40     )
# ---> 41     res_lung_pers = model_pers_lung.run()
#      43     last_state = res_lung_pers.get_nodes_probtraj()
#      44     if len(last_state) < 10:
#
# File ~/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/maboss/simulation.py:275, in Simulation.run(self, command, workdir, overwrite, prefix, cmaboss, only_final_state)
#     272 if overwrite:
#     273     self.overwrite = overwrite
# --> 275 return Result(self, command, self.workdir, self.overwrite, prefix)
#
# File ~/repos/icr/Attractor-Resistance/.env/lib/python3.13/site-packages/maboss/result.py:58, in Result.__init__(self, simul, command, workdir, overwrite, prefix)
#      55 if command:
#      56     maboss_cmd = command
# ---> 58 self._err = subprocess.call([maboss_cmd, "-c", self._cfg, "-o",
#      59                             os.path.join(self._path, self.prefix), self._bnd])
#      60 if self._err:
#      61     print("Error, MaBoSS returned non 0 value", file=stderr)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:397, in call(timeout, *popenargs, **kwargs)
#     395 with Popen(*popenargs, **kwargs) as p:
#     396     try:
# --> 397         return p.wait(timeout=timeout)
#     398     except:  # Including KeyboardInterrupt, wait handled that.
#     399         p.kill()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:1277, in Popen.wait(self, timeout)
#    1275     endtime = _time() + timeout
#    1276 try:
# -> 1277     return self._wait(timeout=timeout)
#    1278 except KeyboardInterrupt:
#    1279     # https://bugs.python.org/issue25942
#    1280     # The first keyboard interrupt waits briefly for the child to
#    1281     # exit under the common assumption that it also received the ^C
#    1282     # generated SIGINT and will exit rapidly.
#    1283     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:2063, in Popen._wait(self, timeout)
#    2061 if self.returncode is not None:
#    2062     break  # Another thread waited.
# -> 2063 (pid, sts) = self._try_wait(0)
#    2064 # Check the pid and loop as waitpid has been known to
#    2065 # return 0 even without WNOHANG in odd situations.
#    2066 # http://bugs.python.org/issue14396.
#    2067 if pid == self.pid:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.3/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py:2021, in Popen._try_wait(self, wait_flags)
#    2019 """All callers to this function MUST hold self._waitpid_lock."""
#    2020 try:
# -> 2021     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2022 except ChildProcessError:
#    2023     # This happens if SIGCLD is set to be ignored or waiting
#    2024     # for child processes has otherwise been disabled for our
#    2025     # process.  This child is dead, we can't get the status.
#    2026     pid = self.pid
#
# KeyboardInterrupt:

# %%
low_group_ids= list(phenotype_data_filtered[phenotype_data_filtered['Gleason_group'] == 'low_aggressive']['sampleID'])
medium_group_ids= list(phenotype_data_filtered[phenotype_data_filtered['Gleason_group'] == 'middle_aggressive']['sampleID'])
high_group_ids= list(phenotype_data_filtered[phenotype_data_filtered['Gleason_group'] == 'high_aggressive']['sampleID'])

# %%
#move each files to directory corresponding

# Map group names to sample ID lists
group_mapping = {
    "low_group": low_group_ids,
    "medium_group": medium_group_ids,
    "high_group": high_group_ids,
}

# Loop over all files in the source directory
for filename in os.listdir(folder_save_results):
    if not filename.startswith("_TCGA"):
        continue
    sample_id = filename.replace("_", "").replace(".csv", "")
    # Determine the group of this sample
    group_found = False
    for group_name, id_list in group_mapping.items():
        if sample_id in id_list:
            group_folder = os.path.join(dest_base_dir, group_name)
            os.makedirs(group_folder, exist_ok=True)

            src_path = os.path.join(folder_save_results, filename)
            dst_path = os.path.join(group_folder, filename)
            shutil.move(src_path, dst_path)

            group_found = True
            break

    if not group_found:
        print(f" Sample ID {sample_id} not found in any group list.")

# %%
# combine all the values
groups = ["low_group", "medium_group", "high_group"]

mean_df = compute_phenotype_mean_group_validation(groups, dest_base_dir)
# Out:
#               Proliferation  Invasion  DNA_Repair  Migration  Apoptosis
# Acidosis           0.366059  0.331998    0.235884   0.024329   0.363642
# Androgen           0.378743  0.352069    0.239454   0.051197   0.364997
# Carcinogen         0.377359  0.345996    0.400864   0.013867   0.411317
# EGF                0.374162  0.347758    0.233172   0.051207   0.367908
# FGF                0.389455  0.347433    0.236985   0.023721   0.381571
# Hypoxia            0.324061  0.339164    0.230691   0.028574   0.365637
# Nutrients          0.399506  0.344355    0.237794   0.030017   0.364394
# SPOP               0.391617  0.371726    0.230629   0.051310   0.341411
# TGFB               0.334074  0.503393    0.227178   0.041223   0.418340
# TNF                0.317056  0.535548    0.226876   0.069388   0.368572
# fused_event        0.372464  0.343281    0.237205   0.025562   0.367195
# Overall_Mean       0.365869  0.378429    0.248794   0.037309   0.374090
#               Proliferation  Invasion  DNA_Repair  Migration  Apoptosis
# Acidosis           0.414578  0.366865    0.296251   0.023305   0.422425
# Androgen           0.427641  0.387040    0.297638   0.044680   0.424479
# Carcinogen         0.419263  0.371813    0.427513   0.011640   0.508042
# EGF                0.427085  0.384857    0.289527   0.042071   0.436486
# FGF                0.435437  0.377376    0.297200   0.017316   0.451563
# Hypoxia            0.373039  0.363537    0.288634   0.026672   0.424615
# Nutrients          0.443389  0.372851    0.297499   0.026651   0.426843
# SPOP               0.438933  0.405813    0.284828   0.050797   0.396372
# TGFB               0.382487  0.539561    0.285905   0.036763   0.503630
# TNF                0.364309  0.581956    0.285498   0.084666   0.418422
# fused_event        0.427920  0.380366    0.296204   0.021745   0.426653
# Overall_Mean       0.414007  0.412003    0.304245   0.035119   0.439957
#               Proliferation  Invasion  DNA_Repair  Migration  Apoptosis
# Acidosis           0.764190  0.771672    0.721894   0.021616   0.750165
# Androgen           0.770516  0.775640    0.721933   0.028250   0.754655
# Carcinogen         0.761939  0.764335    0.729592   0.009607   0.805787
# EGF                0.767550  0.767639    0.697620   0.027183   0.752185
# FGF                0.776341  0.779939    0.722628   0.016280   0.769785
# Hypoxia            0.758065  0.764836    0.704369   0.022750   0.754370
# Nutrients          0.787030  0.770894    0.725452   0.026109   0.760566
# SPOP               0.768500  0.767198    0.693789   0.030251   0.750596
# TGFB               0.761456  0.798023    0.696171   0.030486   0.784621
# TNF                0.753666  0.809890    0.697624   0.042738   0.751204
# fused_event        0.769875  0.771305    0.719067   0.020972   0.757630
# Overall_Mean       0.767193  0.776488    0.711831   0.025113   0.762869

# %%
# combine values of a directory together

def collect_group_data(group_folder_path):
    combined_data = defaultdict(lambda: defaultdict(list))

    for file in os.listdir(group_folder_path):
        if file.startswith("_TCGA") and file.endswith(".csv"):
            file_path = os.path.join(group_folder_path, file)
            df = pd.read_csv(file_path, index_col=0)

            for input_name in df.index:
                for phenotype in df.columns:
                    value = df.at[input_name, phenotype]
                    combined_data[input_name][phenotype].append(float(value))

    result_df = pd.DataFrame.from_dict(combined_data, orient='index')
    result_df.to_csv(os.path.join(group_folder_path, "combined_results.csv"))

    return result_df

group_names = ["low_group", "medium_group", "high_group"]
group_dataframes = {}

for group in group_names:
    folder_path = os.path.join(dest_base_dir, group)
    group_df = collect_group_data(folder_path)
    group_dataframes[group] = group_df

# %%
# Paths to your combined data CSVs

group_files = {
    "low": os.path.join(dest_base_dir, "low_group", "combined_results.csv"),
    "medium": os.path.join(dest_base_dir, "medium_group", "combined_results.csv"),
    "high": os.path.join(dest_base_dir, "high_group", "combined_results.csv"),
}


# Load all groups into dict of DataFrames
group_dfs = {}
for group, path in group_files.items():
    df = pd.read_csv(path, index_col=0)
    df = df.applymap(ast.literal_eval)
    group_dfs[group] = df

# Get all inputs and phenotypes from one dataframe (assuming all share the same shape)
inputs = group_dfs["low"].index
phenotypes = group_dfs["low"].columns
# Prepare result storage
kruskal_results = pd.DataFrame(index=inputs, columns=phenotypes)

# Run Kruskal-Wallis test for each (input, phenotype)
for input_name in inputs:
    for phenotype in phenotypes:
        data_low = group_dfs["low"].at[input_name, phenotype]
        data_medium = group_dfs["medium"].at[input_name, phenotype]
        data_high = group_dfs["high"].at[input_name, phenotype]

        # Run the Kruskal-Wallis test only if all groups have data
        if data_low and data_medium and data_high:
            stat, pvalue = kruskal(data_low, data_medium, data_high)
            kruskal_results.at[input_name, phenotype] = pvalue
        else:
            kruskal_results.at[input_name, phenotype] = None

# Optionally, save the p-values table to CSV
kruskal_results.to_csv(os.path.join(dest_base_dir, "kruskal_pvalues.csv"))
print(kruskal_results)
# Out:
#             Proliferation  Invasion DNA_Repair Migration Apoptosis
# EGF              0.001063  0.000571   0.003473  0.000655  0.001269
# FGF              0.000953  0.000488   0.000663  0.847542  0.000973
# TGFB             0.000558  0.001172   0.001881    0.9022  0.001157
# Androgen         0.001063  0.000585   0.003988   0.89582  0.001246
# Hypoxia           0.00217   0.00061   0.000888  0.000905  0.001296
# Nutrients        0.000853  0.000562   0.001149  0.000825  0.001097
# Carcinogen       0.001197   0.00067    0.00151  0.176619  0.000587
# Acidosis         0.001081  0.000558   0.001752  0.143918  0.001457
# TNF              0.000992  0.001417   0.000463  0.869862  0.001274
# fused_event      0.000985  0.000619   0.004247  0.000962  0.001311
# SPOP             0.001116  0.000642   0.001532  0.914569  0.001974
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_22673/1535223345.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(ast.literal_eval)
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_22673/1535223345.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(ast.literal_eval)
# /var/folders/83/pqwsm5cn7vscbq8l3fnf30qr0000gn/T/ipykernel_22673/1535223345.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(ast.literal_eval)

# %%
# Flatten p-values to a 1D array, ignoring None or NaNs
pvals = kruskal_results.values.flatten()
pvals = [p for p in pvals if p is not None]

# Adjust using BH method
_, pvals_adj, _, _ = multipletests(pvals, alpha=0.05, method='fdr_bh')

# Now, you need to put adjusted p-values back into the DataFrame shape
# Create a copy to fill
adjusted_df = kruskal_results.copy()

# Fill adjusted p-values sequentially where there was a non-None p-value
idx = 0
for i in adjusted_df.index:
    for j in adjusted_df.columns:
        if adjusted_df.at[i, j] is not None:
            adjusted_df.at[i, j] = pvals_adj[idx]
            idx += 1
print(adjusted_df)
# Out:
#             Proliferation  Invasion DNA_Repair Migration Apoptosis
# EGF              0.001948  0.001948   0.004152  0.001948  0.001948
# FGF              0.001948  0.001948   0.001948  0.914015  0.001948
# TGFB             0.001948  0.001948   0.002406  0.914569  0.001948
# Androgen         0.001948  0.001948   0.004667  0.914569  0.001948
# Hypoxia          0.002653  0.001948   0.001948  0.001948  0.001948
# Nutrients        0.001948  0.001948   0.001948  0.001948  0.001948
# Carcinogen       0.001948  0.001948   0.002056   0.19428  0.001948
# Acidosis         0.001948  0.001948   0.002294  0.161541  0.002054
# TNF              0.001948   0.00205   0.001948  0.914569  0.001948
# fused_event      0.001948  0.001948   0.004867  0.001948  0.001948
# SPOP             0.001948  0.001948   0.002056  0.914569  0.002467

# %%
# keep only the significant results
significant_df = adjusted_df.copy()
significant_df[significant_df >= 0.05] = np.nan
significant_df
# Out:
#             Proliferation  Invasion DNA_Repair Migration Apoptosis
# EGF              0.001948  0.001948   0.004152  0.001948  0.001948
# FGF              0.001948  0.001948   0.001948       NaN  0.001948
# TGFB             0.001948  0.001948   0.002406       NaN  0.001948
# Androgen         0.001948  0.001948   0.004667       NaN  0.001948
# Hypoxia          0.002653  0.001948   0.001948  0.001948  0.001948
# Nutrients        0.001948  0.001948   0.001948  0.001948  0.001948
# Carcinogen       0.001948  0.001948   0.002056       NaN  0.001948
# Acidosis         0.001948  0.001948   0.002294       NaN  0.002054
# TNF              0.001948   0.00205   0.001948       NaN  0.001948
# fused_event      0.001948  0.001948   0.004867  0.001948  0.001948
# SPOP             0.001948  0.001948   0.002056       NaN  0.002467
